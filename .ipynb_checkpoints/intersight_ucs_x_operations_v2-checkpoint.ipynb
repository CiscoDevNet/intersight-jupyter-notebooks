# %% [markdown]
# # Getting Physical Compute Inventory from Intersight using the Cisco Intersight REST API with Python
#
# In this lab you learn how to retrieve a list of physical compute inventory from Cisco Intersight.
#
# ## Objectives
#
# The objective of this lab is to show how to:
#
# * Authenticate with the Intersight REST API
# * Call the Intersight REST API to pull a list of physical compute resources
#
# ## Prerequisites
#
# Before getting started with this lab, you will need the following:
#
# * An Intersight account (you may also need a Cisco account for credentials)
# * API key
# * API secret available
#
# ### Background
#
# Intersight has many capabilities and one of them is managing on-premises compute resources such as Cisco UCS servers. The process of making UCS servers available to Intersight is known as a claim. Thus, an administrator must first claim UCS servers before they are available as a resource in Intersight. After a UCS servers are claimed, they show up in inventory as physical compute servers.
#
# In this lab we call the Intersight REST API's using Python and retrieve the inventory of physical compute resources claimed in Intersight.

# %% [markdown]
# ## Step 1: Generate API key and Secret Key
#
# Log into your Intersight account and navigate to **Settings** which is available by clicking the gear icon located towaward the upper-righthand side of the Intersight user interface.

# %% [markdown]
# <img align="left" src="images/intersight-settings.png">

# %% [markdown]
# * Click **API Keys** located in the lefthand column.
# * Click **Generate API Key** located toward the upper-righthand side of the page.
# * Select **API key for OpenAPI schema version 2** in the **Generate API Key** dialog box and provide a description for your API key.
# * Copy the API Key ID and store it somewhere for use in the upcoming steps.
# * Save the **Secret Key** to a text file and make note of its location. Move the file to the same directory where this code is running or make note of its location for use in the upcoming steps.
#
# <img align="left" src="images/api-secret-key-save-as.png">

# %% [markdown]
# > This is the only one time that the secret key can be viewed or downloaded. You cannot recover them later. However, you can create new access keys at any time.

# %% [markdown]
# ## Step 2: Import modules
#
# Let's import `json` and `requests` as well as the `IntersightAuth` method from the `intersight_auth` class.

# %%
import json
import requests

from intersight_auth import IntersightAuth

# %% [markdown]
# ## Step 3: Declare and populate a variable named AUTH
#
# In step 2, you generated a new API Key ID and a Secret Key. Copy/paste the value of the `api_key_id` below as well as the file path for the downloaded file (also from Step 1) named `SecretKey.txt`.

# %%
AUTH = IntersightAuth(
    secret_key_filename='./key/SecretKey.txt',
    api_key_id='596cc79e5d91b400010d15ad/6037f58b7564612d33a5bb70/6139462a7564612d33532a71'
    )

# %% [markdown]
# ## Step 4: Declare and populate a variable with the base URL
# We'll use the base URL of `https://www.intersight.com/api/v1/` for this exercise.

# %%
BURL = 'https://www.intersight.com/api/v1/'

# %% [markdown]
# ## Step 5: GET Phsyical Compute Summary
#
# The GET operations provide insight into the hardware claimed by Intersight. In the example below, we'll get an inventory of compute nodes and see if they are managed by IMM (Intersight Managed Mode).
#
# First, define the resource URI of `compute/PhysicalSummaries` and add it to the base url. Then, make the request  with the full URL along with the `auth` credentials and store Intersight's response in the variable named `response`. The request is in `try` and `except` blocks to handle exceptions.

# %%
resource_path = "compute/PhysicalSummaries"
# Let's add some error handling just in case
try:
    response = requests.get(
                    BURL + resource_path,
                    auth=AUTH
                    )
    response.raise_for_status()

except requests.exceptoins.HTTPError as error:
    print(error) # Anything but a 200 response ends up here

# %% [markdown]
# ## Step 6: Inspect the JSON returned by Intersight
# Take a look at the `Results` data structure. There is a rich set of information returned by Intersight about the phsyical compute devices.

# %%
response.json()['Results']
# Out:
# [{'AccountMoid': '596cc79e5d91b400010d15ad',
#   'AdminPowerState': 'policy',
#   'AlarmSummary': {'ClassId': 'compute.AlarmSummary',
#    'Critical': 1,
#    'ObjectType': 'compute.AlarmSummary',
#    'Warning': 0},
#   'Ancestors': [],
#   'AssetTag': 'Test test',
#   'AvailableMemory': 196608,
#   'BiosPostComplete': False,
#   'ChassisId': '',
#   'ClassId': 'compute.PhysicalSummary',
#   'ConnectionStatus': '',
#   'CpuCapacity': 44,
#   'CreateTime': '2018-04-16T14:27:56.546Z',
#   'DeviceMoId': '5ad4b2e337726e6c33c081b8',
#   'Dn': 'sys/rack-unit-1',
#   'DomainGroupMoid': '5b2541877a7662743465cc98',
#   'FaultSummary': 65536,
#   'Firmware': '3.1(2d)',
#   'InventoryDeviceInfo': None,
#   'Ipv4Address': '172.28.224.103',
#   'KvmIpAddresses': [{'Address': '172.28.224.103',
#     'Category': 'Equipment',
#     'ClassId': 'compute.IpAddress',
#     'DefaultGateway': '172.28.224.1',
#     'Dn': 'sys/rack-unit-1/mgmt/if-1',
#     'HttpPort': 80,
#     'HttpsPort': 443,
#     'KvmPort': 2068,
#     'KvmVlan': 1,
#     'Name': 'Outband',
#     'ObjectType': 'compute.IpAddress',
#     'Subnet': '255.255.254.0',
#     'Type': 'MgmtInterface'}],
#   'ManagementMode': 'IntersightStandalone',
#   'MemorySpeed': '2400',
#   'MgmtIpAddress': '172.28.224.103',
#   'ModTime': '2021-09-14T13:38:04.548Z',
#   'Model': 'HXAF220C-M5SX',
#   'Moid': '5ad4b2ec393130316d129e47',
#   'Name': 'C220-WZP220315M3',
#   'NumAdaptors': 1,
#   'NumCpuCores': 20,
#   'NumCpuCoresEnabled': 20,
#   'NumCpus': 2,
#   'NumEthHostInterfaces': 2,
#   'NumFcHostInterfaces': 2,
#   'NumThreads': 40,
#   'ObjectType': 'compute.PhysicalSummary',
#   'OperPowerState': 'on',
#   'OperReason': [],
#   'OperState': '',
#   'Operability': '',
#   'Owners': ['596cc79e5d91b400010d15ad', '5ad4b2e337726e6c33c081b8'],
#   'PermissionResources': [{'ClassId': 'mo.MoRef',
#     'Moid': '5dde9f116972652d33539d39',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5dde9f116972652d33539d39'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5e4f4ed86972652d336160b6',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5e4f4ed86972652d336160b6'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5e8249da6972652d33ed6bed',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5e8249da6972652d33ed6bed'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5ece73d76972652d33312bcf',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ece73d76972652d33312bcf'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5ee0a9966972652d33e92240',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ee0a9966972652d33e92240'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f07d9d36972652d3315917e',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f07d9d36972652d3315917e'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f7b3bcf6972652d33acb4d4',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f7b3bcf6972652d33acb4d4'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5df841b36972652d33dc0298',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5df841b36972652d33dc0298'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5fe1e5ca6972652d33c384bd',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5fe1e5ca6972652d33c384bd'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '60a65be36972652d33788ab5',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/60a65be36972652d33788ab5'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '60c2356b6972652d33e0c9da',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/60c2356b6972652d33e0c9da'}],
#   'PlatformType': 'IMCM5',
#   'Presence': 'equipped',
#   'RegisteredDevice': {'ClassId': 'mo.MoRef',
#    'Moid': '5ad4b2e337726e6c33c081b8',
#    'ObjectType': 'asset.DeviceRegistration',
#    'link': 'https://www.intersight.com/api/v1/asset/DeviceRegistrations/5ad4b2e337726e6c33c081b8'},
#   'Revision': '',
#   'Rn': '',
#   'ScaledMode': '',
#   'Serial': 'WZP220315M3',
#   'ServerId': 1,
#   'ServiceProfile': '',
#   'SharedScope': '',
#   'SlotId': 0,
#   'SourceObjectType': 'compute.RackUnit',
#   'Tags': [{'Key': 'HX Cluster', 'Value': 'Atlanta'},
#    {'Key': 'Site', 'Value': 'NY'},
#    {'Key': 'Rack', 'Value': 'R13'},
#    {'Key': 'datacenter', 'Value': 'sjc07'},
#    {'Key': 'C-Series', 'Value': 'YES'},
#    {'Key': 'intersight.server.os.updateTimestamp',
#     'Value': '2018-08-30T20:55:00.106Z'},
#    {'Key': 'intersight.server.os.vendor', 'Value': 'VMware ESXi'},
#    {'Key': 'intersight.server.os.name', 'Value': 'ESXi'},
#    {'Key': 'intersight.server.os.arch', 'Value': 'x86_64'},
#    {'Key': 'intersight.server.os.type', 'Value': 'VMkernel'},
#    {'Key': 'intersight.server.os.kernelVersionString', 'Value': '6.0.0'},
#    {'Key': 'intersight.server.os.releaseVersionString',
#     'Value': 'Releasebuild-6921384'},
#    {'Key': 'intersight.server.os.updateVersionString', 'Value': '3'},
#    {'Key': 'intersight.server.os.driver.0.name', 'Value': 'ixgbe'},
#    {'Key': 'intersight.server.os.driver.0.description',
#     'Value': 'Intel(R) Ethernet Controller 10G X550T'},
#    {'Key': 'intersight.server.os.driver.0.version',
#     'Value': 'Version 4.5.2-iov, Build: 2494585, Interface: 9.2 Built on: Apr 13 2017'},
#    {'Key': 'intersight.server.os.driver.1.name', 'Value': 'enic'},
#    {'Key': 'intersight.server.os.driver.1.description',
#     'Value': 'Cisco Systems Inc Cisco VIC Ethernet NIC'},
#    {'Key': 'intersight.server.os.driver.1.version', 'Value': '2.3.0.14'},
#    {'Key': 'intersight.server.os.driver.2.name', 'Value': 'fnic'},
#    {'Key': 'intersight.server.os.driver.2.description',
#     'Value': '(0000:1d:00.3) Cisco Systems Inc Cisco VIC FCoE HBA Driver'},
#    {'Key': 'intersight.server.os.driver.2.version', 'Value': '1.6.0.36'},
#    {'Key': 'intersight.server.os.driver.3.name', 'Value': 'ahci'},
#    {'Key': 'intersight.server.os.driver.3.description',
#     'Value': '(0000:00:11.5) Intel Corporation Lewisburg SATA AHCI Controller'},
#    {'Key': 'intersight.server.os.driver.3.version', 'Value': '3.0-26vmw'},
#    {'Key': 'a1', 'Value': '22'},
#    {'Key': 'Intersight.LicenseTier', 'Value': 'Premier'}],
#   'TopologyScanStatus': '',
#   'TotalMemory': 196608,
#   'UserLabel': 'Stephen test',
#   'Uuid': 'A0EFEAA2-AF76-4B09-987E-6789A68F5534',
#   'Vendor': 'Cisco Systems Inc'},
#  {'AccountMoid': '596cc79e5d91b400010d15ad',
#   'AdminPowerState': 'policy',
#   'AlarmSummary': {'ClassId': 'compute.AlarmSummary',
#    'Critical': 0,
#    'ObjectType': 'compute.AlarmSummary',
#    'Warning': 0},
#   'Ancestors': [],
#   'AssetTag': 'Unknown',
#   'AvailableMemory': 196608,
#   'BiosPostComplete': False,
#   'ChassisId': '',
#   'ClassId': 'compute.PhysicalSummary',
#   'ConnectionStatus': '',
#   'CpuCapacity': 44,
#   'CreateTime': '2018-04-16T14:48:31.591Z',
#   'DeviceMoId': '5ad4b7b437726e6c33c0a25e',
#   'Dn': 'sys/rack-unit-1',
#   'DomainGroupMoid': '5b2541877a7662743465cc98',
#   'FaultSummary': 65536,
#   'Firmware': '3.1(2d)',
#   'InventoryDeviceInfo': None,
#   'Ipv4Address': '172.28.224.105',
#   'KvmIpAddresses': [{'Address': '172.28.224.105',
#     'Category': 'Equipment',
#     'ClassId': 'compute.IpAddress',
#     'DefaultGateway': '172.28.224.1',
#     'Dn': 'sys/rack-unit-1/mgmt/if-1',
#     'HttpPort': 80,
#     'HttpsPort': 443,
#     'KvmPort': 2068,
#     'KvmVlan': 1,
#     'Name': 'Outband',
#     'ObjectType': 'compute.IpAddress',
#     'Subnet': '255.255.254.0',
#     'Type': 'MgmtInterface'}],
#   'ManagementMode': 'IntersightStandalone',
#   'MemorySpeed': '2400',
#   'MgmtIpAddress': '172.28.224.105',
#   'ModTime': '2021-08-23T22:58:08.674Z',
#   'Model': 'HXAF220C-M5SX',
#   'Moid': '5ad4b7bf393130316d138429',
#   'Name': 'C220-WZP22040938',
#   'NumAdaptors': 1,
#   'NumCpuCores': 20,
#   'NumCpuCoresEnabled': 20,
#   'NumCpus': 2,
#   'NumEthHostInterfaces': 2,
#   'NumFcHostInterfaces': 2,
#   'NumThreads': 40,
#   'ObjectType': 'compute.PhysicalSummary',
#   'OperPowerState': 'on',
#   'OperReason': [],
#   'OperState': '',
#   'Operability': '',
#   'Owners': ['596cc79e5d91b400010d15ad', '5ad4b7b437726e6c33c0a25e'],
#   'PermissionResources': [{'ClassId': 'mo.MoRef',
#     'Moid': '5dde9f116972652d33539d39',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5dde9f116972652d33539d39'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5e4f4ed86972652d336160b6',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5e4f4ed86972652d336160b6'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5e8249da6972652d33ed6bed',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5e8249da6972652d33ed6bed'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5ece73d76972652d33312bcf',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ece73d76972652d33312bcf'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5ee0a9966972652d33e92240',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ee0a9966972652d33e92240'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f7b3bcf6972652d33acb4d4',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f7b3bcf6972652d33acb4d4'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5df841b36972652d33dc0298',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5df841b36972652d33dc0298'}],
#   'PlatformType': 'IMCM5',
#   'Presence': 'equipped',
#   'RegisteredDevice': {'ClassId': 'mo.MoRef',
#    'Moid': '5ad4b7b437726e6c33c0a25e',
#    'ObjectType': 'asset.DeviceRegistration',
#    'link': 'https://www.intersight.com/api/v1/asset/DeviceRegistrations/5ad4b7b437726e6c33c0a25e'},
#   'Revision': '',
#   'Rn': '',
#   'ScaledMode': '',
#   'Serial': 'WZP22040938',
#   'ServerId': 1,
#   'ServiceProfile': '',
#   'SharedScope': '',
#   'SlotId': 0,
#   'SourceObjectType': 'compute.RackUnit',
#   'Tags': [{'Key': 'Demo', 'Value': 'Yes'},
#    {'Key': 'HX Cluster', 'Value': 'Atlanta'},
#    {'Key': 'intersight.server.os.updateTimestamp',
#     'Value': '2018-08-30T20:55:02.093Z'},
#    {'Key': 'intersight.server.os.vendor', 'Value': 'VMware ESXi'},
#    {'Key': 'intersight.server.os.name', 'Value': 'ESXi'},
#    {'Key': 'intersight.server.os.arch', 'Value': 'x86_64'},
#    {'Key': 'intersight.server.os.type', 'Value': 'VMkernel'},
#    {'Key': 'intersight.server.os.kernelVersionString', 'Value': '6.0.0'},
#    {'Key': 'intersight.server.os.releaseVersionString',
#     'Value': 'Releasebuild-6921384'},
#    {'Key': 'intersight.server.os.updateVersionString', 'Value': '3'},
#    {'Key': 'intersight.server.os.driver.0.name', 'Value': 'ixgbe'},
#    {'Key': 'intersight.server.os.driver.0.description',
#     'Value': 'Intel(R) Ethernet Controller 10G X550T'},
#    {'Key': 'intersight.server.os.driver.0.version',
#     'Value': 'Version 4.5.2-iov, Build: 2494585, Interface: 9.2 Built on: Apr 13 2017'},
#    {'Key': 'intersight.server.os.driver.1.name', 'Value': 'enic'},
#    {'Key': 'intersight.server.os.driver.1.description',
#     'Value': 'Cisco Systems Inc Cisco VIC Ethernet NIC'},
#    {'Key': 'intersight.server.os.driver.1.version', 'Value': '2.3.0.14'},
#    {'Key': 'intersight.server.os.driver.2.name', 'Value': 'fnic'},
#    {'Key': 'intersight.server.os.driver.2.description',
#     'Value': '(0000:1d:00.3) Cisco Systems Inc Cisco VIC FCoE HBA Driver'},
#    {'Key': 'intersight.server.os.driver.2.version', 'Value': '1.6.0.36'},
#    {'Key': 'intersight.server.os.driver.3.name', 'Value': 'ahci'},
#    {'Key': 'intersight.server.os.driver.3.description',
#     'Value': '(0000:00:11.5) Intel Corporation Lewisburg SATA AHCI Controller'},
#    {'Key': 'intersight.server.os.driver.3.version', 'Value': '3.0-26vmw'},
#    {'Key': 'Site', 'Value': 'NY'},
#    {'Key': 'Rack', 'Value': 'R13'},
#    {'Key': 'datacenter', 'Value': 'sjc07'},
#    {'Key': 'test', 'Value': 'test'},
#    {'Key': 'Intersight.LicenseTier', 'Value': 'Advantage'}],
#   'TopologyScanStatus': '',
#   'TotalMemory': 196608,
#   'UserLabel': 'labelTes',
#   'Uuid': 'D81A3DBE-30B8-49F5-955A-0355616CAC23',
#   'Vendor': 'Cisco Systems Inc'},
#  {'AccountMoid': '596cc79e5d91b400010d15ad',
#   'AdminPowerState': 'policy',
#   'AlarmSummary': {'ClassId': 'compute.AlarmSummary',
#    'Critical': 0,
#    'ObjectType': 'compute.AlarmSummary',
#    'Warning': 0},
#   'Ancestors': [],
#   'AssetTag': 'Unknown',
#   'AvailableMemory': 196608,
#   'BiosPostComplete': False,
#   'ChassisId': '',
#   'ClassId': 'compute.PhysicalSummary',
#   'ConnectionStatus': '',
#   'CpuCapacity': 44,
#   'CreateTime': '2018-04-16T14:48:30.858Z',
#   'DeviceMoId': '5ad4b7af37726e6c33c0a23d',
#   'Dn': 'sys/rack-unit-1',
#   'DomainGroupMoid': '5b2541877a7662743465cc98',
#   'FaultSummary': 65536,
#   'Firmware': '3.1(2d)',
#   'InventoryDeviceInfo': None,
#   'Ipv4Address': '172.28.224.104',
#   'KvmIpAddresses': [{'Address': '172.28.224.104',
#     'Category': 'Equipment',
#     'ClassId': 'compute.IpAddress',
#     'DefaultGateway': '172.28.224.1',
#     'Dn': 'sys/rack-unit-1/mgmt/if-1',
#     'HttpPort': 80,
#     'HttpsPort': 443,
#     'KvmPort': 2068,
#     'KvmVlan': 1,
#     'Name': 'Outband',
#     'ObjectType': 'compute.IpAddress',
#     'Subnet': '255.255.254.0',
#     'Type': 'MgmtInterface'}],
#   'ManagementMode': 'IntersightStandalone',
#   'MemorySpeed': '2400',
#   'MgmtIpAddress': '172.28.224.104',
#   'ModTime': '2021-09-14T16:54:21.966Z',
#   'Model': 'HXAF220C-M5SX',
#   'Moid': '5ad4b7be393130316d1383ac',
#   'Name': 'C220-WZP22040093',
#   'NumAdaptors': 1,
#   'NumCpuCores': 20,
#   'NumCpuCoresEnabled': 20,
#   'NumCpus': 2,
#   'NumEthHostInterfaces': 2,
#   'NumFcHostInterfaces': 2,
#   'NumThreads': 40,
#   'ObjectType': 'compute.PhysicalSummary',
#   'OperPowerState': 'on',
#   'OperReason': [],
#   'OperState': '',
#   'Operability': '',
#   'Owners': ['596cc79e5d91b400010d15ad', '5ad4b7af37726e6c33c0a23d'],
#   'PermissionResources': [{'ClassId': 'mo.MoRef',
#     'Moid': '5dde9f116972652d33539d39',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5dde9f116972652d33539d39'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5e4f4ed86972652d336160b6',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5e4f4ed86972652d336160b6'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5e8249da6972652d33ed6bed',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5e8249da6972652d33ed6bed'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5ece73d76972652d33312bcf',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ece73d76972652d33312bcf'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5ee0a9966972652d33e92240',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ee0a9966972652d33e92240'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f7b3bcf6972652d33acb4d4',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f7b3bcf6972652d33acb4d4'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5df841b36972652d33dc0298',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5df841b36972652d33dc0298'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '60a65be36972652d33788ab5',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/60a65be36972652d33788ab5'}],
#   'PlatformType': 'IMCM5',
#   'Presence': 'equipped',
#   'RegisteredDevice': {'ClassId': 'mo.MoRef',
#    'Moid': '5ad4b7af37726e6c33c0a23d',
#    'ObjectType': 'asset.DeviceRegistration',
#    'link': 'https://www.intersight.com/api/v1/asset/DeviceRegistrations/5ad4b7af37726e6c33c0a23d'},
#   'Revision': '',
#   'Rn': '',
#   'ScaledMode': '',
#   'Serial': 'WZP22040093',
#   'ServerId': 1,
#   'ServiceProfile': '',
#   'SharedScope': '',
#   'SlotId': 0,
#   'SourceObjectType': 'compute.RackUnit',
#   'Tags': [{'Key': 'Demo', 'Value': 'Yes'},
#    {'Key': 'HX Cluster', 'Value': 'Atlanta'},
#    {'Key': 'intersight.server.os.updateTimestamp',
#     'Value': '2018-08-30T20:55:01.045Z'},
#    {'Key': 'intersight.server.os.vendor', 'Value': 'VMware ESXi'},
#    {'Key': 'intersight.server.os.name', 'Value': 'ESXi'},
#    {'Key': 'intersight.server.os.arch', 'Value': 'x86_64'},
#    {'Key': 'intersight.server.os.type', 'Value': 'VMkernel'},
#    {'Key': 'intersight.server.os.kernelVersionString', 'Value': '6.0.0'},
#    {'Key': 'intersight.server.os.releaseVersionString',
#     'Value': 'Releasebuild-6921384'},
#    {'Key': 'intersight.server.os.updateVersionString', 'Value': '3'},
#    {'Key': 'intersight.server.os.driver.0.name', 'Value': 'ixgbe'},
#    {'Key': 'intersight.server.os.driver.0.description',
#     'Value': 'Intel(R) Ethernet Controller 10G X550T'},
#    {'Key': 'intersight.server.os.driver.0.version',
#     'Value': 'Version 4.5.2-iov, Build: 2494585, Interface: 9.2 Built on: Apr 13 2017'},
#    {'Key': 'intersight.server.os.driver.1.name', 'Value': 'enic'},
#    {'Key': 'intersight.server.os.driver.1.description',
#     'Value': 'Cisco Systems Inc Cisco VIC Ethernet NIC'},
#    {'Key': 'intersight.server.os.driver.1.version', 'Value': '2.3.0.14'},
#    {'Key': 'intersight.server.os.driver.2.name', 'Value': 'fnic'},
#    {'Key': 'intersight.server.os.driver.2.description',
#     'Value': '(0000:1d:00.3) Cisco Systems Inc Cisco VIC FCoE HBA Driver'},
#    {'Key': 'intersight.server.os.driver.2.version', 'Value': '1.6.0.36'},
#    {'Key': 'intersight.server.os.driver.3.name', 'Value': 'ahci'},
#    {'Key': 'intersight.server.os.driver.3.description',
#     'Value': '(0000:00:11.5) Intel Corporation Lewisburg SATA AHCI Controller'},
#    {'Key': 'intersight.server.os.driver.3.version', 'Value': '3.0-26vmw'},
#    {'Key': 'Site', 'Value': 'NY'},
#    {'Key': 'Rack', 'Value': 'R13'},
#    {'Key': 'datacenter', 'Value': 'sjc07'},
#    {'Key': 'location', 'Value': 'odessa'},
#    {'Key': 'Intersight.LicenseTier', 'Value': 'Advantage'}],
#   'TopologyScanStatus': '',
#   'TotalMemory': 196608,
#   'UserLabel': '',
#   'Uuid': '47F52C0A-A276-4526-A9F6-2DD3B3A60A0E',
#   'Vendor': 'Cisco Systems Inc'},
#  {'AccountMoid': '596cc79e5d91b400010d15ad',
#   'AdminPowerState': 'policy',
#   'AlarmSummary': {'ClassId': 'compute.AlarmSummary',
#    'Critical': 1,
#    'ObjectType': 'compute.AlarmSummary',
#    'Warning': 1},
#   'Ancestors': [],
#   'AssetTag': 'Unknown',
#   'AvailableMemory': 196608,
#   'BiosPostComplete': False,
#   'ChassisId': '',
#   'ClassId': 'compute.PhysicalSummary',
#   'ConnectionStatus': '',
#   'CpuCapacity': 44,
#   'CreateTime': '2018-04-16T14:48:40.995Z',
#   'DeviceMoId': '5ad4b7be37726e6c33c0a2b3',
#   'Dn': 'sys/rack-unit-1',
#   'DomainGroupMoid': '5b2541877a7662743465cc98',
#   'FaultSummary': 131073,
#   'Firmware': '3.1(2d)',
#   'InventoryDeviceInfo': None,
#   'Ipv4Address': '172.28.224.109',
#   'KvmIpAddresses': [{'Address': '172.28.224.109',
#     'Category': 'Equipment',
#     'ClassId': 'compute.IpAddress',
#     'DefaultGateway': '172.28.224.1',
#     'Dn': 'sys/rack-unit-1/mgmt/if-1',
#     'HttpPort': 80,
#     'HttpsPort': 443,
#     'KvmPort': 2068,
#     'KvmVlan': 1,
#     'Name': 'Outband',
#     'ObjectType': 'compute.IpAddress',
#     'Subnet': '255.255.254.0',
#     'Type': 'MgmtInterface'}],
#   'ManagementMode': 'IntersightStandalone',
#   'MemorySpeed': '2400',
#   'MgmtIpAddress': '172.28.224.109',
#   'ModTime': '2021-09-14T10:50:16.746Z',
#   'Model': 'HXAF220C-M5SX',
#   'Moid': '5ad4b7c8393130316d1387cb',
#   'Name': 'C220-WZP220315UC',
#   'NumAdaptors': 1,
#   'NumCpuCores': 20,
#   'NumCpuCoresEnabled': 20,
#   'NumCpus': 2,
#   'NumEthHostInterfaces': 2,
#   'NumFcHostInterfaces': 2,
#   'NumThreads': 40,
#   'ObjectType': 'compute.PhysicalSummary',
#   'OperPowerState': 'on',
#   'OperReason': [],
#   'OperState': '',
#   'Operability': '',
#   'Owners': ['596cc79e5d91b400010d15ad', '5ad4b7be37726e6c33c0a2b3'],
#   'PermissionResources': [{'ClassId': 'mo.MoRef',
#     'Moid': '5dde9f116972652d33539d39',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5dde9f116972652d33539d39'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5e4f4ed86972652d336160b6',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5e4f4ed86972652d336160b6'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5ee0a9966972652d33e92240',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ee0a9966972652d33e92240'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f7b3bcf6972652d33acb4d4',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f7b3bcf6972652d33acb4d4'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5df841b36972652d33dc0298',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5df841b36972652d33dc0298'}],
#   'PlatformType': 'IMCM5',
#   'Presence': 'equipped',
#   'RegisteredDevice': {'ClassId': 'mo.MoRef',
#    'Moid': '5ad4b7be37726e6c33c0a2b3',
#    'ObjectType': 'asset.DeviceRegistration',
#    'link': 'https://www.intersight.com/api/v1/asset/DeviceRegistrations/5ad4b7be37726e6c33c0a2b3'},
#   'Revision': '',
#   'Rn': '',
#   'ScaledMode': '',
#   'Serial': 'WZP220315UC',
#   'ServerId': 1,
#   'ServiceProfile': '',
#   'SharedScope': '',
#   'SlotId': 0,
#   'SourceObjectType': 'compute.RackUnit',
#   'Tags': [{'Key': 'Demo', 'Value': 'Yes'},
#    {'Key': 'Site', 'Value': 'NY'},
#    {'Key': 'Rack', 'Value': 'R13'},
#    {'Key': 'datacenter', 'Value': 'sjc07'},
#    {'Key': 'intersight.server.os.updateTimestamp',
#     'Value': '2018-08-30T20:54:56.718Z'},
#    {'Key': 'intersight.server.os.vendor', 'Value': 'VMware ESXi'},
#    {'Key': 'intersight.server.os.name', 'Value': 'ESXi'},
#    {'Key': 'intersight.server.os.arch', 'Value': 'x86_64'},
#    {'Key': 'intersight.server.os.type', 'Value': 'VMkernel'},
#    {'Key': 'intersight.server.os.kernelVersionString', 'Value': '6.0.0'},
#    {'Key': 'intersight.server.os.releaseVersionString',
#     'Value': 'Releasebuild-6921384'},
#    {'Key': 'intersight.server.os.updateVersionString', 'Value': '3'},
#    {'Key': 'intersight.server.os.driver.0.name', 'Value': 'ixgbe'},
#    {'Key': 'intersight.server.os.driver.0.description',
#     'Value': 'Intel(R) Ethernet Controller 10G X550T'},
#    {'Key': 'intersight.server.os.driver.0.version',
#     'Value': 'Version 4.5.2-iov, Build: 2494585, Interface: 9.2 Built on: Apr 13 2017'},
#    {'Key': 'intersight.server.os.driver.1.name', 'Value': 'enic'},
#    {'Key': 'intersight.server.os.driver.1.description',
#     'Value': 'Cisco Systems Inc Cisco VIC Ethernet NIC'},
#    {'Key': 'intersight.server.os.driver.1.version', 'Value': '2.3.0.14'},
#    {'Key': 'intersight.server.os.driver.2.name', 'Value': 'fnic'},
#    {'Key': 'intersight.server.os.driver.2.description',
#     'Value': '(0000:1e:00.0) Cisco Systems Inc Cisco VIC FCoE HBA Driver'},
#    {'Key': 'intersight.server.os.driver.2.version', 'Value': '1.6.0.36'},
#    {'Key': 'intersight.server.os.driver.3.name', 'Value': 'ahci'},
#    {'Key': 'intersight.server.os.driver.3.description',
#     'Value': '(0000:00:11.5) Intel Corporation Lewisburg SATA AHCI Controller'},
#    {'Key': 'intersight.server.os.driver.3.version', 'Value': '3.0-26vmw'},
#    {'Key': 'Intersight.LicenseTier', 'Value': 'Essential'}],
#   'TopologyScanStatus': '',
#   'TotalMemory': 196608,
#   'UserLabel': 'labe',
#   'Uuid': '6004EB93-2480-4C69-A2D3-451770D9A55F',
#   'Vendor': 'Cisco Systems Inc'},
#  {'AccountMoid': '596cc79e5d91b400010d15ad',
#   'AdminPowerState': 'policy',
#   'AlarmSummary': {'ClassId': 'compute.AlarmSummary',
#    'Critical': 0,
#    'ObjectType': 'compute.AlarmSummary',
#    'Warning': 0},
#   'Ancestors': [],
#   'AssetTag': 'Unknown',
#   'AvailableMemory': 196608,
#   'BiosPostComplete': False,
#   'ChassisId': '',
#   'ClassId': 'compute.PhysicalSummary',
#   'ConnectionStatus': '',
#   'CpuCapacity': 44,
#   'CreateTime': '2018-04-16T14:48:48.191Z',
#   'DeviceMoId': '5ad4b7c637726e6c33c0a399',
#   'Dn': 'sys/rack-unit-1',
#   'DomainGroupMoid': '5b2541877a7662743465cc98',
#   'FaultSummary': 65536,
#   'Firmware': '3.1(2d)',
#   'InventoryDeviceInfo': None,
#   'Ipv4Address': '172.28.224.111',
#   'KvmIpAddresses': [{'Address': '172.28.224.111',
#     'Category': 'Equipment',
#     'ClassId': 'compute.IpAddress',
#     'DefaultGateway': '172.28.224.1',
#     'Dn': 'sys/rack-unit-1/mgmt/if-1',
#     'HttpPort': 80,
#     'HttpsPort': 443,
#     'KvmPort': 2068,
#     'KvmVlan': 1,
#     'Name': 'Outband',
#     'ObjectType': 'compute.IpAddress',
#     'Subnet': '255.255.254.0',
#     'Type': 'MgmtInterface'}],
#   'ManagementMode': 'IntersightStandalone',
#   'MemorySpeed': '2400',
#   'MgmtIpAddress': '172.28.224.111',
#   'ModTime': '2021-09-14T04:30:01.436Z',
#   'Model': 'HXAF220C-M5SX',
#   'Moid': '5ad4b7d0393130316d138a2b',
#   'Name': 'C220-WZP2204001N',
#   'NumAdaptors': 1,
#   'NumCpuCores': 20,
#   'NumCpuCoresEnabled': 20,
#   'NumCpus': 2,
#   'NumEthHostInterfaces': 2,
#   'NumFcHostInterfaces': 2,
#   'NumThreads': 40,
#   'ObjectType': 'compute.PhysicalSummary',
#   'OperPowerState': 'on',
#   'OperReason': [],
#   'OperState': '',
#   'Operability': '',
#   'Owners': ['596cc79e5d91b400010d15ad', '5ad4b7c637726e6c33c0a399'],
#   'PermissionResources': [{'ClassId': 'mo.MoRef',
#     'Moid': '5dde9f116972652d33539d39',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5dde9f116972652d33539d39'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5e4f4ed86972652d336160b6',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5e4f4ed86972652d336160b6'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5ee0a9966972652d33e92240',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ee0a9966972652d33e92240'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f7b3bcf6972652d33acb4d4',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f7b3bcf6972652d33acb4d4'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5df841b36972652d33dc0298',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5df841b36972652d33dc0298'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f7d83376972652d33fa78e6',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f7d83376972652d33fa78e6'}],
#   'PlatformType': 'IMCM5',
#   'Presence': 'equipped',
#   'RegisteredDevice': {'ClassId': 'mo.MoRef',
#    'Moid': '5ad4b7c637726e6c33c0a399',
#    'ObjectType': 'asset.DeviceRegistration',
#    'link': 'https://www.intersight.com/api/v1/asset/DeviceRegistrations/5ad4b7c637726e6c33c0a399'},
#   'Revision': '',
#   'Rn': '',
#   'ScaledMode': '',
#   'Serial': 'WZP2204001N',
#   'ServerId': 1,
#   'ServiceProfile': '',
#   'SharedScope': '',
#   'SlotId': 0,
#   'SourceObjectType': 'compute.RackUnit',
#   'Tags': [{'Key': 'Demo', 'Value': 'Yes'},
#    {'Key': 'intersight.server.os.updateTimestamp',
#     'Value': '2018-08-30T20:54:59.077Z'},
#    {'Key': 'intersight.server.os.vendor', 'Value': 'VMware ESXi'},
#    {'Key': 'intersight.server.os.name', 'Value': 'ESXi'},
#    {'Key': 'intersight.server.os.arch', 'Value': 'x86_64'},
#    {'Key': 'intersight.server.os.type', 'Value': 'VMkernel'},
#    {'Key': 'intersight.server.os.kernelVersionString', 'Value': '6.0.0'},
#    {'Key': 'intersight.server.os.releaseVersionString',
#     'Value': 'Releasebuild-6921384'},
#    {'Key': 'intersight.server.os.updateVersionString', 'Value': '3'},
#    {'Key': 'intersight.server.os.driver.0.name', 'Value': 'ixgbe'},
#    {'Key': 'intersight.server.os.driver.0.description',
#     'Value': 'Intel(R) Ethernet Controller 10G X550T'},
#    {'Key': 'intersight.server.os.driver.0.version',
#     'Value': 'Version 4.5.2-iov, Build: 2494585, Interface: 9.2 Built on: Apr 13 2017'},
#    {'Key': 'intersight.server.os.driver.1.name', 'Value': 'enic'},
#    {'Key': 'intersight.server.os.driver.1.description',
#     'Value': 'Cisco Systems Inc Cisco VIC Ethernet NIC'},
#    {'Key': 'intersight.server.os.driver.1.version', 'Value': '2.3.0.14'},
#    {'Key': 'intersight.server.os.driver.2.name', 'Value': 'fnic'},
#    {'Key': 'intersight.server.os.driver.2.description',
#     'Value': '(0000:1d:00.3) Cisco Systems Inc Cisco VIC FCoE HBA Driver'},
#    {'Key': 'intersight.server.os.driver.2.version', 'Value': '1.6.0.36'},
#    {'Key': 'intersight.server.os.driver.3.name', 'Value': 'ahci'},
#    {'Key': 'intersight.server.os.driver.3.description',
#     'Value': '(0000:00:11.5) Intel Corporation Lewisburg SATA AHCI Controller'},
#    {'Key': 'intersight.server.os.driver.3.version', 'Value': '3.0-26vmw'},
#    {'Key': 'Site', 'Value': 'NY'},
#    {'Key': 'Rack', 'Value': 'R13'},
#    {'Key': 'datacenter', 'Value': 'sjc07'},
#    {'Key': 'Intersight.LicenseTier', 'Value': 'Essential'}],
#   'TopologyScanStatus': '',
#   'TotalMemory': 196608,
#   'UserLabel': '',
#   'Uuid': '8EBD5047-FFEB-44A6-836E-687BDBA3ACC4',
#   'Vendor': 'Cisco Systems Inc'},
#  {'AccountMoid': '596cc79e5d91b400010d15ad',
#   'AdminPowerState': 'policy',
#   'AlarmSummary': {'ClassId': 'compute.AlarmSummary',
#    'Critical': 0,
#    'ObjectType': 'compute.AlarmSummary',
#    'Warning': 0},
#   'Ancestors': [],
#   'AssetTag': 'Unknown',
#   'AvailableMemory': 196608,
#   'BiosPostComplete': False,
#   'ChassisId': '',
#   'ClassId': 'compute.PhysicalSummary',
#   'ConnectionStatus': '',
#   'CpuCapacity': 44,
#   'CreateTime': '2018-04-16T14:48:48.505Z',
#   'DeviceMoId': '5ad4b7c637726e6c33c0a3b1',
#   'Dn': 'sys/rack-unit-1',
#   'DomainGroupMoid': '5b2541877a7662743465cc98',
#   'FaultSummary': 65536,
#   'Firmware': '3.1(2d)',
#   'InventoryDeviceInfo': None,
#   'Ipv4Address': '172.28.224.110',
#   'KvmIpAddresses': [{'Address': '172.28.224.110',
#     'Category': 'Equipment',
#     'ClassId': 'compute.IpAddress',
#     'DefaultGateway': '172.28.224.1',
#     'Dn': 'sys/rack-unit-1/mgmt/if-1',
#     'HttpPort': 80,
#     'HttpsPort': 443,
#     'KvmPort': 2068,
#     'KvmVlan': 1,
#     'Name': 'Outband',
#     'ObjectType': 'compute.IpAddress',
#     'Subnet': '255.255.254.0',
#     'Type': 'MgmtInterface'}],
#   'ManagementMode': 'IntersightStandalone',
#   'MemorySpeed': '2400',
#   'MgmtIpAddress': '172.28.224.110',
#   'ModTime': '2021-09-14T12:21:16.142Z',
#   'Model': 'HXAF220C-M5SX',
#   'Moid': '5ad4b7d0393130316d138a3f',
#   'Name': 'C220-WZP22040085',
#   'NumAdaptors': 1,
#   'NumCpuCores': 20,
#   'NumCpuCoresEnabled': 20,
#   'NumCpus': 2,
#   'NumEthHostInterfaces': 2,
#   'NumFcHostInterfaces': 2,
#   'NumThreads': 40,
#   'ObjectType': 'compute.PhysicalSummary',
#   'OperPowerState': 'on',
#   'OperReason': [],
#   'OperState': '',
#   'Operability': '',
#   'Owners': ['596cc79e5d91b400010d15ad', '5ad4b7c637726e6c33c0a3b1'],
#   'PermissionResources': [{'ClassId': 'mo.MoRef',
#     'Moid': '5dde9f116972652d33539d39',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5dde9f116972652d33539d39'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5e4f4ed86972652d336160b6',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5e4f4ed86972652d336160b6'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5ee0a9966972652d33e92240',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ee0a9966972652d33e92240'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f7b3bcf6972652d33acb4d4',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f7b3bcf6972652d33acb4d4'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5df841b36972652d33dc0298',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5df841b36972652d33dc0298'}],
#   'PlatformType': 'IMCM5',
#   'Presence': 'equipped',
#   'RegisteredDevice': {'ClassId': 'mo.MoRef',
#    'Moid': '5ad4b7c637726e6c33c0a3b1',
#    'ObjectType': 'asset.DeviceRegistration',
#    'link': 'https://www.intersight.com/api/v1/asset/DeviceRegistrations/5ad4b7c637726e6c33c0a3b1'},
#   'Revision': '',
#   'Rn': '',
#   'ScaledMode': '',
#   'Serial': 'WZP22040085',
#   'ServerId': 1,
#   'ServiceProfile': '',
#   'SharedScope': '',
#   'SlotId': 0,
#   'SourceObjectType': 'compute.RackUnit',
#   'Tags': [{'Key': 'Demo', 'Value': 'Yes'},
#    {'Key': 'Site', 'Value': 'NY'},
#    {'Key': 'Rack', 'Value': 'R13'},
#    {'Key': 'datacenter', 'Value': 'sjc07'},
#    {'Key': 'TME', 'Value': 'Matt'},
#    {'Key': 'intersight.server.os.updateTimestamp',
#     'Value': '2018-08-30T20:54:57.981Z'},
#    {'Key': 'intersight.server.os.vendor', 'Value': 'VMware ESXi'},
#    {'Key': 'intersight.server.os.name', 'Value': 'ESXi'},
#    {'Key': 'intersight.server.os.arch', 'Value': 'x86_64'},
#    {'Key': 'intersight.server.os.type', 'Value': 'VMkernel'},
#    {'Key': 'intersight.server.os.kernelVersionString', 'Value': '6.0.0'},
#    {'Key': 'intersight.server.os.releaseVersionString',
#     'Value': 'Releasebuild-6921384'},
#    {'Key': 'intersight.server.os.updateVersionString', 'Value': '3'},
#    {'Key': 'intersight.server.os.driver.0.name', 'Value': 'ixgbe'},
#    {'Key': 'intersight.server.os.driver.0.description',
#     'Value': 'Intel(R) Ethernet Controller 10G X550T'},
#    {'Key': 'intersight.server.os.driver.0.version',
#     'Value': 'Version 4.5.2-iov, Build: 2494585, Interface: 9.2 Built on: Apr 13 2017'},
#    {'Key': 'intersight.server.os.driver.1.name', 'Value': 'enic'},
#    {'Key': 'intersight.server.os.driver.1.description',
#     'Value': 'Cisco Systems Inc Cisco VIC Ethernet NIC'},
#    {'Key': 'intersight.server.os.driver.1.version', 'Value': '2.3.0.14'},
#    {'Key': 'intersight.server.os.driver.2.name', 'Value': 'fnic'},
#    {'Key': 'intersight.server.os.driver.2.description',
#     'Value': '(0000:1d:00.3) Cisco Systems Inc Cisco VIC FCoE HBA Driver'},
#    {'Key': 'intersight.server.os.driver.2.version', 'Value': '1.6.0.36'},
#    {'Key': 'intersight.server.os.driver.3.name', 'Value': 'ahci'},
#    {'Key': 'intersight.server.os.driver.3.description',
#     'Value': '(0000:00:11.5) Intel Corporation Lewisburg SATA AHCI Controller'},
#    {'Key': 'intersight.server.os.driver.3.version', 'Value': '3.0-26vmw'},
#    {'Key': 'Intersight.LicenseTier', 'Value': 'Essential'}],
#   'TopologyScanStatus': '',
#   'TotalMemory': 196608,
#   'UserLabel': '',
#   'Uuid': '555A9117-A269-4418-9C89-07CE61125133',
#   'Vendor': 'Cisco Systems Inc'},
#  {'AccountMoid': '596cc79e5d91b400010d15ad',
#   'AdminPowerState': 'policy',
#   'AlarmSummary': {'ClassId': 'compute.AlarmSummary',
#    'Critical': 1,
#    'ObjectType': 'compute.AlarmSummary',
#    'Warning': 1},
#   'Ancestors': [],
#   'AssetTag': 'Unknown',
#   'AvailableMemory': 196608,
#   'BiosPostComplete': False,
#   'ChassisId': '',
#   'ClassId': 'compute.PhysicalSummary',
#   'ConnectionStatus': '',
#   'CpuCapacity': 44,
#   'CreateTime': '2018-11-07T14:10:57.639Z',
#   'DeviceMoId': '5be2f25e646d6d7878a6592a',
#   'Dn': 'sys/rack-unit-1',
#   'DomainGroupMoid': '5b2541877a7662743465cc98',
#   'FaultSummary': 65537,
#   'Firmware': '4.1(0.128)',
#   'InventoryDeviceInfo': None,
#   'Ipv4Address': '10.94.143.230',
#   'KvmIpAddresses': [{'Address': '10.94.143.230',
#     'Category': 'Equipment',
#     'ClassId': 'compute.IpAddress',
#     'DefaultGateway': '10.94.143.1',
#     'Dn': 'sys/rack-unit-1/mgmt/if-1',
#     'HttpPort': 80,
#     'HttpsPort': 443,
#     'KvmPort': 2068,
#     'KvmVlan': 1,
#     'Name': 'Outband',
#     'ObjectType': 'compute.IpAddress',
#     'Subnet': '255.255.255.0',
#     'Type': 'MgmtInterface'}],
#   'ManagementMode': 'IntersightStandalone',
#   'MemorySpeed': '2400',
#   'MgmtIpAddress': '10.94.143.230',
#   'ModTime': '2021-03-21T15:15:19.859Z',
#   'Model': 'HX220C-M5SX',
#   'Moid': '5be2f2716467726274d6902e',
#   'Name': ' C220-WZP21421OPA',
#   'NumAdaptors': 1,
#   'NumCpuCores': 20,
#   'NumCpuCoresEnabled': 20,
#   'NumCpus': 2,
#   'NumEthHostInterfaces': 8,
#   'NumFcHostInterfaces': 4,
#   'NumThreads': 40,
#   'ObjectType': 'compute.PhysicalSummary',
#   'OperPowerState': 'on',
#   'OperReason': [],
#   'OperState': '',
#   'Operability': '',
#   'Owners': ['596cc79e5d91b400010d15ad', '5be2f25e646d6d7878a6592a'],
#   'PermissionResources': [{'ClassId': 'mo.MoRef',
#     'Moid': '5dde9f116972652d33539d39',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5dde9f116972652d33539d39'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5e4f4ed86972652d336160b6',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5e4f4ed86972652d336160b6'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5ee0a9966972652d33e92240',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ee0a9966972652d33e92240'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f7b3bcf6972652d33acb4d4',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f7b3bcf6972652d33acb4d4'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5df841b36972652d33dc0298',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5df841b36972652d33dc0298'}],
#   'PlatformType': 'IMC',
#   'Presence': 'equipped',
#   'RegisteredDevice': {'ClassId': 'mo.MoRef',
#    'Moid': '5be2f25e646d6d7878a6592a',
#    'ObjectType': 'asset.DeviceRegistration',
#    'link': 'https://www.intersight.com/api/v1/asset/DeviceRegistrations/5be2f25e646d6d7878a6592a'},
#   'Revision': '',
#   'Rn': '',
#   'ScaledMode': '',
#   'Serial': 'WZP21421OPA',
#   'ServerId': 1,
#   'ServiceProfile': '',
#   'SharedScope': '',
#   'SlotId': 0,
#   'SourceObjectType': 'compute.RackUnit',
#   'Tags': [{'Key': 'Brad', 'Value': 'Demo'},
#    {'Key': 'Intersight.LicenseTier', 'Value': 'Advantage'},
#    {'Key': 'Site', 'Value': 'NY'}],
#   'TopologyScanStatus': '',
#   'TotalMemory': 196608,
#   'UserLabel': '',
#   'Uuid': '3769D720-F628-4921-8B14-6BDAF37371E5',
#   'Vendor': 'Cisco Systems Inc'},
#  {'AccountMoid': '596cc79e5d91b400010d15ad',
#   'AdminPowerState': 'policy',
#   'AlarmSummary': {'ClassId': 'compute.AlarmSummary',
#    'Critical': 0,
#    'ObjectType': 'compute.AlarmSummary',
#    'Warning': 0},
#   'Ancestors': [],
#   'AssetTag': 'Unknown',
#   'AvailableMemory': 196608,
#   'BiosPostComplete': False,
#   'ChassisId': '',
#   'ClassId': 'compute.PhysicalSummary',
#   'ConnectionStatus': '',
#   'CpuCapacity': 0,
#   'CreateTime': '2018-11-07T14:14:30.686Z',
#   'DeviceMoId': '5be2f2ea646d6d7878a66c9e',
#   'Dn': 'sys/rack-unit-1',
#   'DomainGroupMoid': '5b2541877a7662743465cc98',
#   'FaultSummary': 0,
#   'Firmware': '4.0(2c)',
#   'InventoryDeviceInfo': None,
#   'Ipv4Address': '',
#   'KvmIpAddresses': [{'Address': '10.94.145.47',
#     'Category': 'Equipment',
#     'ClassId': 'compute.IpAddress',
#     'DefaultGateway': '10.94.145.1',
#     'Dn': 'sys/rack-unit-1/mgmt/if-1',
#     'HttpPort': 80,
#     'HttpsPort': 443,
#     'KvmPort': 2068,
#     'KvmVlan': 1,
#     'Name': 'Outband',
#     'ObjectType': 'compute.IpAddress',
#     'Subnet': '255.255.255.0',
#     'Type': 'MgmtInterface'}],
#   'ManagementMode': 'IntersightStandalone',
#   'MemorySpeed': '2400',
#   'MgmtIpAddress': '10.94.145.47',
#   'ModTime': '2021-03-11T20:45:03.463Z',
#   'Model': 'HX220C-M5SX',
#   'Moid': '5be2f3466467726274d6b66b',
#   'Name': ' C220-WZP21421OKT',
#   'NumAdaptors': 2,
#   'NumCpuCores': 20,
#   'NumCpuCoresEnabled': 20,
#   'NumCpus': 2,
#   'NumEthHostInterfaces': 8,
#   'NumFcHostInterfaces': 4,
#   'NumThreads': 40,
#   'ObjectType': 'compute.PhysicalSummary',
#   'OperPowerState': 'on',
#   'OperReason': [],
#   'OperState': '',
#   'Operability': '',
#   'Owners': ['596cc79e5d91b400010d15ad', '5be2f2ea646d6d7878a66c9e'],
#   'PermissionResources': [{'ClassId': 'mo.MoRef',
#     'Moid': '5dde9f116972652d33539d39',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5dde9f116972652d33539d39'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5e4f4ed86972652d336160b6',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5e4f4ed86972652d336160b6'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5ee0a9966972652d33e92240',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ee0a9966972652d33e92240'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f7b3bcf6972652d33acb4d4',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f7b3bcf6972652d33acb4d4'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5df841b36972652d33dc0298',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5df841b36972652d33dc0298'}],
#   'PlatformType': 'IMC',
#   'Presence': 'equipped',
#   'RegisteredDevice': {'ClassId': 'mo.MoRef',
#    'Moid': '5be2f2ea646d6d7878a66c9e',
#    'ObjectType': 'asset.DeviceRegistration',
#    'link': 'https://www.intersight.com/api/v1/asset/DeviceRegistrations/5be2f2ea646d6d7878a66c9e'},
#   'Revision': '',
#   'Rn': '',
#   'ScaledMode': '',
#   'Serial': 'WZP21421OKT',
#   'ServerId': 1,
#   'ServiceProfile': '',
#   'SharedScope': '',
#   'SlotId': 0,
#   'SourceObjectType': 'compute.RackUnit',
#   'Tags': [{'Key': 'Intersight.LicenseTier', 'Value': 'Essential'},
#    {'Key': 'Site', 'Value': 'NY'}],
#   'TopologyScanStatus': '',
#   'TotalMemory': 196608,
#   'UserLabel': '',
#   'Uuid': '188A0AF9-1464-4F5C-96D8-8AD0202F77CC',
#   'Vendor': 'Cisco Systems Inc'},
#  {'AccountMoid': '596cc79e5d91b400010d15ad',
#   'AdminPowerState': 'policy',
#   'AlarmSummary': {'ClassId': 'compute.AlarmSummary',
#    'Critical': 0,
#    'ObjectType': 'compute.AlarmSummary',
#    'Warning': 0},
#   'Ancestors': [],
#   'AssetTag': 'Unknown',
#   'AvailableMemory': 393216,
#   'BiosPostComplete': False,
#   'ChassisId': '',
#   'ClassId': 'compute.PhysicalSummary',
#   'ConnectionStatus': '',
#   'CpuCapacity': 67.2,
#   'CreateTime': '2019-05-14T16:49:24.504Z',
#   'DeviceMoId': '5cdaf1756f72612d31fafb9c',
#   'Dn': 'sys/rack-unit-1',
#   'DomainGroupMoid': '5b2541877a7662743465cc98',
#   'FaultSummary': 0,
#   'Firmware': '4.0(2f)',
#   'InventoryDeviceInfo': None,
#   'Ipv4Address': '10.94.143.235',
#   'KvmIpAddresses': [{'Address': '10.94.143.235',
#     'Category': 'Equipment',
#     'ClassId': 'compute.IpAddress',
#     'DefaultGateway': '10.94.143.1',
#     'Dn': 'sys/rack-unit-1/mgmt/if-1',
#     'HttpPort': 80,
#     'HttpsPort': 443,
#     'KvmPort': 2068,
#     'KvmVlan': 1,
#     'Name': 'Outband',
#     'ObjectType': 'compute.IpAddress',
#     'Subnet': '255.255.255.0',
#     'Type': 'MgmtInterface'}],
#   'ManagementMode': 'IntersightStandalone',
#   'MemorySpeed': '2666',
#   'MgmtIpAddress': '10.94.143.235',
#   'ModTime': '2021-08-27T02:11:23.949Z',
#   'Model': 'HXAF220C-M5SX',
#   'Moid': '5cdaf1946176752d31befa92',
#   'Name': 'C220-WZP220216UQ',
#   'NumAdaptors': 3,
#   'NumCpuCores': 32,
#   'NumCpuCoresEnabled': 32,
#   'NumCpus': 2,
#   'NumEthHostInterfaces': 8,
#   'NumFcHostInterfaces': 2,
#   'NumThreads': 64,
#   'ObjectType': 'compute.PhysicalSummary',
#   'OperPowerState': 'on',
#   'OperReason': [],
#   'OperState': '',
#   'Operability': '',
#   'Owners': ['596cc79e5d91b400010d15ad', '5cdaf1756f72612d31fafb9c'],
#   'PermissionResources': [{'ClassId': 'mo.MoRef',
#     'Moid': '5dde9f116972652d33539d39',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5dde9f116972652d33539d39'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5e4f4ed86972652d336160b6',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5e4f4ed86972652d336160b6'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5ee0a9966972652d33e92240',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ee0a9966972652d33e92240'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f7b3bcf6972652d33acb4d4',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f7b3bcf6972652d33acb4d4'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5df841b36972652d33dc0298',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5df841b36972652d33dc0298'}],
#   'PlatformType': 'IMCM5',
#   'Presence': 'equipped',
#   'RegisteredDevice': {'ClassId': 'mo.MoRef',
#    'Moid': '5cdaf1756f72612d31fafb9c',
#    'ObjectType': 'asset.DeviceRegistration',
#    'link': 'https://www.intersight.com/api/v1/asset/DeviceRegistrations/5cdaf1756f72612d31fafb9c'},
#   'Revision': '',
#   'Rn': '',
#   'ScaledMode': '',
#   'Serial': 'WZP220216UQ',
#   'ServerId': 1,
#   'ServiceProfile': '',
#   'SharedScope': '',
#   'SlotId': 0,
#   'SourceObjectType': 'compute.RackUnit',
#   'Tags': [{'Key': 'Brad', 'Value': 'Demo'},
#    {'Key': 'Intersight.LicenseTier', 'Value': 'Advantage'},
#    {'Key': 'Site', 'Value': 'NY'}],
#   'TopologyScanStatus': '',
#   'TotalMemory': 393216,
#   'UserLabel': '',
#   'Uuid': '6AB02A6C-7104-4D8E-8009-C7296179CE8F',
#   'Vendor': 'Cisco Systems Inc'},
#  {'AccountMoid': '596cc79e5d91b400010d15ad',
#   'AdminPowerState': 'policy',
#   'AlarmSummary': {'ClassId': 'compute.AlarmSummary',
#    'Critical': 0,
#    'ObjectType': 'compute.AlarmSummary',
#    'Warning': 0},
#   'Ancestors': [],
#   'AssetTag': 'Unknown',
#   'AvailableMemory': 393216,
#   'BiosPostComplete': False,
#   'ChassisId': '',
#   'ClassId': 'compute.PhysicalSummary',
#   'ConnectionStatus': '',
#   'CpuCapacity': 67.2,
#   'CreateTime': '2019-05-14T16:51:49.271Z',
#   'DeviceMoId': '5cdaf1f16f72612d31fafeee',
#   'Dn': 'sys/rack-unit-1',
#   'DomainGroupMoid': '5b2541877a7662743465cc98',
#   'FaultSummary': 0,
#   'Firmware': '4.0(2f)',
#   'InventoryDeviceInfo': None,
#   'Ipv4Address': '10.94.143.234',
#   'KvmIpAddresses': [{'Address': '10.94.143.234',
#     'Category': 'Equipment',
#     'ClassId': 'compute.IpAddress',
#     'DefaultGateway': '10.94.143.1',
#     'Dn': 'sys/rack-unit-1/mgmt/if-1',
#     'HttpPort': 80,
#     'HttpsPort': 443,
#     'KvmPort': 2068,
#     'KvmVlan': 1,
#     'Name': 'Outband',
#     'ObjectType': 'compute.IpAddress',
#     'Subnet': '255.255.255.0',
#     'Type': 'MgmtInterface'}],
#   'ManagementMode': 'IntersightStandalone',
#   'MemorySpeed': '2666',
#   'MgmtIpAddress': '10.94.143.234',
#   'ModTime': '2021-09-14T15:23:15.454Z',
#   'Model': 'HXAF220C-M5SX',
#   'Moid': '5cdaf2256176752d31bf5206',
#   'Name': 'C220-WZP220216W9',
#   'NumAdaptors': 3,
#   'NumCpuCores': 32,
#   'NumCpuCoresEnabled': 32,
#   'NumCpus': 2,
#   'NumEthHostInterfaces': 8,
#   'NumFcHostInterfaces': 2,
#   'NumThreads': 64,
#   'ObjectType': 'compute.PhysicalSummary',
#   'OperPowerState': 'on',
#   'OperReason': [],
#   'OperState': '',
#   'Operability': '',
#   'Owners': ['596cc79e5d91b400010d15ad', '5cdaf1f16f72612d31fafeee'],
#   'PermissionResources': [{'ClassId': 'mo.MoRef',
#     'Moid': '5dde9f116972652d33539d39',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5dde9f116972652d33539d39'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5e4f4ed86972652d336160b6',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5e4f4ed86972652d336160b6'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5ee0a9966972652d33e92240',
#     'ObjectType': 'organization.Organization',
# ...
#   'InventoryDeviceInfo': None,
#   'Ipv4Address': '10.193.14.228',
#   'KvmIpAddresses': [{'Address': '10.193.14.228',
#     'Category': 'Equipment',
#     'ClassId': 'compute.IpAddress',
#     'DefaultGateway': '10.193.14.1',
#     'Dn': 'sys/chassis-1/blade-2/mgmt/ipv4-pooled-addr',
#     'HttpPort': 80,
#     'HttpsPort': 443,
#     'KvmPort': 2068,
#     'KvmVlan': 0,
#     'Name': 'Outband',
#     'ObjectType': 'compute.IpAddress',
#     'Subnet': '255.255.255.0',
#     'Type': 'VnicIpV4PooledAddr'}],
#   'ManagementMode': 'UCSM',
#   'MemorySpeed': '3200',
#   'MgmtIpAddress': '10.193.14.228',
#   'ModTime': '2021-07-15T19:00:11.32Z',
#   'Model': 'UCSB-B200-M6',
#   'Moid': '5f4ebf4f6176752d37dc2c4b',
#   'Name': 'Lab-146-BetaTest-1-2',
#   'NumAdaptors': 2,
#   'NumCpuCores': 72,
#   'NumCpuCoresEnabled': 72,
#   'NumCpus': 2,
#   'NumEthHostInterfaces': 0,
#   'NumFcHostInterfaces': 0,
#   'NumThreads': 144,
#   'ObjectType': 'compute.PhysicalSummary',
#   'OperPowerState': 'off',
#   'OperReason': [],
#   'OperState': 'unassociated',
#   'Operability': 'operable',
#   'Owners': ['596cc79e5d91b400010d15ad', '5efb9c546f72612d3107ec38'],
#   'Parent': {'ClassId': 'mo.MoRef',
#    'Moid': '5efe60e66176752d3768d3b3',
#    'ObjectType': 'equipment.Chassis',
#    'link': 'https://www.intersight.com/api/v1/equipment/Chasses/5efe60e66176752d3768d3b3'},
#   'PermissionResources': [{'ClassId': 'mo.MoRef',
#     'Moid': '5ee0a9966972652d33e92240',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ee0a9966972652d33e92240'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f7b3bcf6972652d33acb4d4',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f7b3bcf6972652d33acb4d4'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5dde9f116972652d33539d39',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5dde9f116972652d33539d39'}],
#   'PlatformType': 'UCSFI',
#   'Presence': 'equipped',
#   'RegisteredDevice': {'ClassId': 'mo.MoRef',
#    'Moid': '5efb9c546f72612d3107ec38',
#    'ObjectType': 'asset.DeviceRegistration',
#    'link': 'https://www.intersight.com/api/v1/asset/DeviceRegistrations/5efb9c546f72612d3107ec38'},
#   'Revision': '0',
#   'Rn': '',
#   'ScaledMode': 'none',
#   'Serial': 'FCH24387E6G',
#   'ServerId': 0,
#   'ServiceProfile': 'org-root/ls-b2',
#   'SharedScope': '',
#   'SlotId': 2,
#   'SourceObjectType': 'compute.Blade',
#   'Tags': [{'Key': 'Intersight.LicenseTier', 'Value': 'Premier'}],
#   'TopologyScanStatus': '',
#   'TotalMemory': 1048576,
#   'UserLabel': '',
#   'Uuid': 'f0545899-04de-428e-8732-c6218c1bc588',
#   'Vendor': 'Cisco Systems Inc'},
#  {'AccountMoid': '596cc79e5d91b400010d15ad',
#   'AdminPowerState': 'policy',
#   'AlarmSummary': {'ClassId': 'compute.AlarmSummary',
#    'Critical': 0,
#    'ObjectType': 'compute.AlarmSummary',
#    'Warning': 0},
#   'Ancestors': [],
#   'AssetTag': '',
#   'AvailableMemory': 8192,
#   'BiosPostComplete': False,
#   'ChassisId': '',
#   'ClassId': 'compute.PhysicalSummary',
#   'ConnectionStatus': '',
#   'CpuCapacity': 10.200001,
#   'CreateTime': '2020-10-02T16:34:22.317Z',
#   'DeviceMoId': '5f7756756f72612d313afa31',
#   'Dn': 'sys/rack-unit-1',
#   'DomainGroupMoid': '5b2541877a7662743465cc98',
#   'FaultSummary': 0,
#   'Firmware': '4.1(1h)',
#   'InventoryDeviceInfo': None,
#   'Ipv4Address': '10.29.141.106',
#   'KvmIpAddresses': [{'Address': '10.29.141.106',
#     'Category': 'Equipment',
#     'ClassId': 'compute.IpAddress',
#     'DefaultGateway': '10.29.141.1',
#     'Dn': 'sys/rack-unit-1/mgmt/if-1',
#     'HttpPort': 80,
#     'HttpsPort': 443,
#     'KvmPort': 2068,
#     'KvmVlan': 141,
#     'Name': 'Outband',
#     'ObjectType': 'compute.IpAddress',
#     'Subnet': '255.255.255.0',
#     'Type': 'MgmtInterface'}],
#   'ManagementMode': 'IntersightStandalone',
#   'MemorySpeed': '2133',
#   'MgmtIpAddress': '10.29.141.106',
#   'ModTime': '2021-01-22T20:05:47.242Z',
#   'Model': 'UCSC-C220-M5SX',
#   'Moid': '5f77568e6176752d37b15bf8',
#   'Name': ' C220-WZP214303YM',
#   'NumAdaptors': 1,
#   'NumCpuCores': 6,
#   'NumCpuCoresEnabled': 6,
#   'NumCpus': 1,
#   'NumEthHostInterfaces': 2,
#   'NumFcHostInterfaces': 2,
#   'NumThreads': 6,
#   'ObjectType': 'compute.PhysicalSummary',
#   'OperPowerState': 'on',
#   'OperReason': None,
#   'OperState': '',
#   'Operability': '',
#   'Owners': ['596cc79e5d91b400010d15ad', '5f7756756f72612d313afa31'],
#   'PermissionResources': [{'ClassId': 'mo.MoRef',
#     'Moid': '5ee0a9966972652d33e92240',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ee0a9966972652d33e92240'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f7b3bcf6972652d33acb4d4',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f7b3bcf6972652d33acb4d4'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5df841b36972652d33dc0298',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5df841b36972652d33dc0298'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5dde9f116972652d33539d39',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5dde9f116972652d33539d39'}],
#   'PlatformType': 'IMC',
#   'Presence': 'equipped',
#   'RegisteredDevice': {'ClassId': 'mo.MoRef',
#    'Moid': '5f7756756f72612d313afa31',
#    'ObjectType': 'asset.DeviceRegistration',
#    'link': 'https://www.intersight.com/api/v1/asset/DeviceRegistrations/5f7756756f72612d313afa31'},
#   'Revision': '',
#   'Rn': '',
#   'ScaledMode': '',
#   'Serial': 'WZP214303YM',
#   'ServerId': 1,
#   'ServiceProfile': '',
#   'SharedScope': '',
#   'SlotId': 0,
#   'SourceObjectType': 'compute.RackUnit',
#   'Tags': [{'Key': 'Intersight.LicenseTier', 'Value': 'Essential'}],
#   'TopologyScanStatus': '',
#   'TotalMemory': 8192,
#   'UserLabel': '',
#   'Uuid': '71870185-BA97-4124-B541-0A7C4BC8FF82',
#   'Vendor': 'Cisco Systems Inc'},
#  {'AccountMoid': '596cc79e5d91b400010d15ad',
#   'AdminPowerState': 'policy',
#   'AlarmSummary': {'ClassId': 'compute.AlarmSummary',
#    'Critical': 0,
#    'ObjectType': 'compute.AlarmSummary',
#    'Warning': 0},
#   'Ancestors': [],
#   'AssetTag': 'Unknown',
#   'AvailableMemory': 65536,
#   'BiosPostComplete': False,
#   'ChassisId': '',
#   'ClassId': 'compute.PhysicalSummary',
#   'ConnectionStatus': '',
#   'CpuCapacity': 76.8,
#   'CreateTime': '2020-10-06T16:06:21.936Z',
#   'DeviceMoId': '5f7c95e46f72612d319c1bc2',
#   'Dn': 'sys/rack-unit-1',
#   'DomainGroupMoid': '5b2541877a7662743465cc98',
#   'FaultSummary': 65537,
#   'Firmware': '4.1(1h)',
#   'InventoryDeviceInfo': None,
#   'Ipv4Address': '10.29.141.111',
#   'KvmIpAddresses': [{'Address': '10.29.141.111',
#     'Category': 'Equipment',
#     'ClassId': 'compute.IpAddress',
#     'DefaultGateway': '10.29.141.1',
#     'Dn': 'sys/rack-unit-1/mgmt/if-1',
#     'HttpPort': 80,
#     'HttpsPort': 443,
#     'KvmPort': 2068,
#     'KvmVlan': 1,
#     'Name': 'Outband',
#     'ObjectType': 'compute.IpAddress',
#     'Subnet': '255.255.255.0',
#     'Type': 'MgmtInterface'}],
#   'ManagementMode': 'IntersightStandalone',
#   'MemorySpeed': '2667',
#   'MgmtIpAddress': '10.29.141.111',
#   'ModTime': '2021-09-13T22:52:24.571Z',
#   'Model': 'UCSC-C125',
#   'Moid': '5f7c95fd6176752d3772649a',
#   'Name': 'C125-WZP220814DQ',
#   'NumAdaptors': 1,
#   'NumCpuCores': 32,
#   'NumCpuCoresEnabled': 32,
#   'NumCpus': 2,
#   'NumEthHostInterfaces': 0,
#   'NumFcHostInterfaces': 0,
#   'NumThreads': 64,
#   'ObjectType': 'compute.PhysicalSummary',
#   'OperPowerState': 'off',
#   'OperReason': [],
#   'OperState': '',
#   'Operability': '',
#   'Owners': ['596cc79e5d91b400010d15ad', '5f7c95e46f72612d319c1bc2'],
#   'PermissionResources': [{'ClassId': 'mo.MoRef',
#     'Moid': '5ee0a9966972652d33e92240',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ee0a9966972652d33e92240'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f7b3bcf6972652d33acb4d4',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f7b3bcf6972652d33acb4d4'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5dde9f116972652d33539d39',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5dde9f116972652d33539d39'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5df841b36972652d33dc0298',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5df841b36972652d33dc0298'}],
#   'PlatformType': 'IMCM5',
#   'Presence': 'equipped',
#   'RegisteredDevice': {'ClassId': 'mo.MoRef',
#    'Moid': '5f7c95e46f72612d319c1bc2',
#    'ObjectType': 'asset.DeviceRegistration',
#    'link': 'https://www.intersight.com/api/v1/asset/DeviceRegistrations/5f7c95e46f72612d319c1bc2'},
#   'Revision': '',
#   'Rn': '',
#   'ScaledMode': '',
#   'Serial': 'WZP220814DQ',
#   'ServerId': 1,
#   'ServiceProfile': '',
#   'SharedScope': '',
#   'SlotId': 0,
#   'SourceObjectType': 'compute.RackUnit',
#   'Tags': [{'Key': 'Intersight.LicenseTier', 'Value': 'Essential'}],
#   'TopologyScanStatus': '',
#   'TotalMemory': 65536,
#   'UserLabel': '',
#   'Uuid': 'E08C6247-E27F-48A0-BAE2-50EC0AD3AAD1',
#   'Vendor': 'Cisco Systems Inc'},
#  {'AccountMoid': '596cc79e5d91b400010d15ad',
#   'AdminPowerState': '',
#   'AlarmSummary': {'ClassId': 'compute.AlarmSummary',
#    'Critical': 0,
#    'ObjectType': 'compute.AlarmSummary',
#    'Warning': 0},
#   'Ancestors': [{'ClassId': 'mo.MoRef',
#     'Moid': '5f90563f6176752d37620206',
#     'ObjectType': 'equipment.Chassis',
#     'link': 'https://www.intersight.com/api/v1/equipment/Chasses/5f90563f6176752d37620206'}],
#   'AssetTag': 'Unknown',
#   'AvailableMemory': 384,
#   'BiosPostComplete': True,
#   'ChassisId': '1',
#   'ClassId': 'compute.PhysicalSummary',
#   'ConnectionStatus': '',
#   'CpuCapacity': 160,
#   'CreateTime': '2020-10-21T15:40:51.416Z',
#   'DeviceMoId': '5f9056746f72612d314dab91',
#   'Dn': '/redfish/v1/Systems/FLM2341053L',
#   'DomainGroupMoid': '5b2541877a7662743465cc98',
#   'FaultSummary': 0,
#   'Firmware': '4.1(32a)',
#   'InventoryDeviceInfo': None,
#   'Ipv4Address': 'fe80::a653:eff:fead:ce11%vlan4043',
#   'KvmIpAddresses': [],
#   'ManagementMode': 'Intersight',
#   'MemorySpeed': '2933',
#   'MgmtIpAddress': '',
#   'ModTime': '2021-09-10T05:40:41.584Z',
#   'Model': 'UCSB-B200-M5',
#   'Moid': '5f9056836176752d376221f8',
#   'Name': 'IMM-SJC07-TME-1-1',
#   'NumAdaptors': 2,
#   'NumCpuCores': 40,
#   'NumCpuCoresEnabled': 40,
#   'NumCpus': 2,
#   'NumEthHostInterfaces': 0,
#   'NumFcHostInterfaces': 0,
#   'NumThreads': 80,
#   'ObjectType': 'compute.PhysicalSummary',
#   'OperPowerState': 'on',
#   'OperReason': [],
#   'OperState': 'OK',
#   'Operability': '',
#   'Owners': ['596cc79e5d91b400010d15ad',
#    '5f90524c6f72612d314cf1f5',
#    '5f9056746f72612d314dab91'],
#   'Parent': {'ClassId': 'mo.MoRef',
#    'Moid': '5f90563f6176752d37620206',
#    'ObjectType': 'equipment.Chassis',
#    'link': 'https://www.intersight.com/api/v1/equipment/Chasses/5f90563f6176752d37620206'},
#   'PermissionResources': [{'ClassId': 'mo.MoRef',
#     'Moid': '5ee0a9966972652d33e92240',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ee0a9966972652d33e92240'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f7b3bcf6972652d33acb4d4',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f7b3bcf6972652d33acb4d4'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f90538f6972652d33b7efb0',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f90538f6972652d33b7efb0'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5dde9f116972652d33539d39',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5dde9f116972652d33539d39'}],
#   'PlatformType': 'IMCBlade',
#   'Presence': 'equipped',
#   'RegisteredDevice': {'ClassId': 'mo.MoRef',
#    'Moid': '5f9056746f72612d314dab91',
#    'ObjectType': 'asset.DeviceRegistration',
#    'link': 'https://www.intersight.com/api/v1/asset/DeviceRegistrations/5f9056746f72612d314dab91'},
#   'Revision': '',
#   'Rn': '',
#   'ScaledMode': '',
#   'Serial': 'FLM2341053L',
#   'ServerId': 0,
#   'ServiceProfile': '',
#   'SharedScope': '',
#   'SlotId': 1,
#   'SourceObjectType': 'compute.Blade',
#   'Tags': [{'Key': 'Intersight.LicenseTier', 'Value': 'Essential'},
#    {'Key': 'tag1', 'Value': 'test'}],
#   'TopologyScanStatus': '',
#   'TotalMemory': 393216,
#   'UserLabel': '',
#   'Uuid': '4B5DBB79-C918-4713-9F10-617221827DFE',
#   'Vendor': 'Cisco Systems Inc.'},
#  {'AccountMoid': '596cc79e5d91b400010d15ad',
#   'AdminPowerState': '',
#   'AlarmSummary': {'ClassId': 'compute.AlarmSummary',
#    'Critical': 0,
#    'ObjectType': 'compute.AlarmSummary',
#    'Warning': 0},
#   'Ancestors': [{'ClassId': 'mo.MoRef',
#     'Moid': '5f90563f6176752d37620206',
#     'ObjectType': 'equipment.Chassis',
#     'link': 'https://www.intersight.com/api/v1/equipment/Chasses/5f90563f6176752d37620206'}],
#   'AssetTag': 'Unknown',
#   'AvailableMemory': 384,
#   'BiosPostComplete': True,
#   'ChassisId': '1',
#   'ClassId': 'compute.PhysicalSummary',
#   'ConnectionStatus': '',
#   'CpuCapacity': 160,
#   'CreateTime': '2020-10-21T15:41:09.892Z',
#   'DeviceMoId': '5f9056876f72612d314daf37',
#   'Dn': '/redfish/v1/Systems/FLM234101BH',
#   'DomainGroupMoid': '5b2541877a7662743465cc98',
#   'FaultSummary': 0,
#   'Firmware': '4.1(32a)',
#   'InventoryDeviceInfo': None,
#   'Ipv4Address': 'fe80::a653:eff:fead:c749%vlan4043',
#   'KvmIpAddresses': [],
#   'ManagementMode': 'Intersight',
#   'MemorySpeed': '2933',
#   'MgmtIpAddress': '',
#   'ModTime': '2021-09-10T05:07:38.664Z',
#   'Model': 'UCSB-B200-M5',
#   'Moid': '5f9056956176752d3762293d',
#   'Name': 'IMM-SJC07-TME-1-2',
#   'NumAdaptors': 2,
#   'NumCpuCores': 40,
#   'NumCpuCoresEnabled': 40,
#   'NumCpus': 2,
#   'NumEthHostInterfaces': 0,
#   'NumFcHostInterfaces': 0,
#   'NumThreads': 80,
#   'ObjectType': 'compute.PhysicalSummary',
#   'OperPowerState': 'on',
#   'OperReason': [],
#   'OperState': 'OK',
#   'Operability': '',
#   'Owners': ['596cc79e5d91b400010d15ad',
#    '5f90524c6f72612d314cf1f5',
#    '5f9056876f72612d314daf37'],
#   'Parent': {'ClassId': 'mo.MoRef',
#    'Moid': '5f90563f6176752d37620206',
#    'ObjectType': 'equipment.Chassis',
#    'link': 'https://www.intersight.com/api/v1/equipment/Chasses/5f90563f6176752d37620206'},
#   'PermissionResources': [{'ClassId': 'mo.MoRef',
#     'Moid': '5ee0a9966972652d33e92240',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5ee0a9966972652d33e92240'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f7b3bcf6972652d33acb4d4',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f7b3bcf6972652d33acb4d4'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5f90538f6972652d33b7efb0',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5f90538f6972652d33b7efb0'},
#    {'ClassId': 'mo.MoRef',
#     'Moid': '5dde9f116972652d33539d39',
#     'ObjectType': 'organization.Organization',
#     'link': 'https://www.intersight.com/api/v1/organization/Organizations/5dde9f116972652d33539d39'}],
#   'PlatformType': 'IMCBlade',
#   'Presence': 'equipped',
#   'RegisteredDevice': {'ClassId': 'mo.MoRef',
#    'Moid': '5f9056876f72612d314daf37',
#    'ObjectType': 'asset.DeviceRegistration',
#    'link': 'https://www.intersight.com/api/v1/asset/DeviceRegistrations/5f9056876f72612d314daf37'},
#   'Revision': '',
#   'Rn': '',
#   'ScaledMode': '',
#   'Serial': 'FLM234101BH',
#   'ServerId': 0,
#   'ServiceProfile': '',
#   'SharedScope': '',
#   'SlotId': 2,
#   'SourceObjectType': 'compute.Blade',
#   'Tags': [{'Key': 'Intersight.LicenseTier', 'Value': 'Essential'}],
#   'TopologyScanStatus': '',
#   'TotalMemory': 393216,
#   'UserLabel': '',
#   'Uuid': 'A934E2E4-D668-4205-B7BE-FF02B05B66B6',
#   'Vendor': 'Cisco Systems Inc.'}]

# %% [markdown]
# ## Step 7. See how many items were returned by `Results`
# `Results` is a list which we can pass `response.json()['Results']` to the `len()` BIF (Built In Function) to see how many results are returned. The result tell us how many physical compute items are contained in the list.

# %%
len(response.json()['Results'])
# Out:
# 100

# %% [markdown]
# ## Step 8. Bringing it all together
# Great! Now we see the number of physical compute devices and now we can pull more information from the returned JSON and organize it by Device, Chassis ID, Management Mode, Model, Memory, and CPU. The information in the `Management Mode` column shows if the phsyical compute device is managed in Intersight Management Mode.
#
# > Intersight Managed Mode (IMM) is a new architecture that manages the UCS Fabric Interconnected systems through a Redfish-based standard model. If you are familiar with the UCS blades, it means the Fabric Interconnect is fully managed by Intersight. Instead of having the familiar UCSM (UCS Manager) interface available directly from the Fabric Interconnect, the interface and all of the Fabric Interconnect operations are managed by Intersight.
#
# We do some CLI formatting to organize our data and see the type of compute hardware managed by Intersight along with its resources (memory and CPU). Then, we iterate over the JSON data and pull the data we're interested in. In this instance, the Model shows the UCS-X series hardware.
#
# > Experiment! See if you can add more information to the list below by choosing other items from the returned JSON data above. For example, you could add a column with `NumCpuCores` and or `Ipv4Address` to the code below. There's no right or wrong answer as to which columns you would like displayed.

# %%
print ("{:<8} {:12} {:<21} {:<15} {:<10} {:<10}".format(
       'Device',
       'Chassis ID',
       'Management Mode',
       'Model',
        'Memory',
        'CPU'))
for num, items in enumerate(response.json()['Results'], start=1):
    print (
        "{:<8} {:<12} {:<21} {:<15} {:<10} {:<10}".format(
            num, 
            items['ChassisId'], 
            items['ManagementMode'], 
            items['Model'], 
            items['AvailableMemory'], 
            items['CpuCapacity']))
# Out:
# Device   Chassis ID   Management Mode       Model           Memory     CPU
# 1                     IntersightStandalone  HXAF220C-M5SX   196608     44
# 2                     IntersightStandalone  HXAF220C-M5SX   196608     44
# 3                     IntersightStandalone  HXAF220C-M5SX   196608     44
# 4                     IntersightStandalone  HXAF220C-M5SX   196608     44
# 5                     IntersightStandalone  HXAF220C-M5SX   196608     44
# 6                     IntersightStandalone  HXAF220C-M5SX   196608     44
# 7                     IntersightStandalone  HX220C-M5SX     196608     44
# 8                     IntersightStandalone  HX220C-M5SX     196608     0
# 9                     IntersightStandalone  HXAF220C-M5SX   393216     67.2
# 10                    IntersightStandalone  HXAF220C-M5SX   393216     67.2
# 11                    IntersightStandalone  UCSC-C220-M5L   196608     62.399998
# 12                    IntersightStandalone  UCSC-C240-M4SX  393216     60
# 13       1            UCSM                  UCSB-B200-M4    262144     72.799995
# 14       2            UCSM                  UCSB-B200-M3    262144     56
# 15       2            UCSM                  UCSB-B200-M4    131072     46
# 16       2            UCSM                  UCSB-B200-M3    131072     32
# 17       2            UCSM                  UCSB-B200-M3    262144     56
# 18       2            UCSM                  UCSB-B200-M4    131072     46
# 19       4            UCSM                  UCSB-B200-M3    262144     56
# 20       3            UCSM                  UCSB-B200-M4    131072     46
# 21       3            UCSM                  UCSB-B200-M3    262144     56
# 22       4            UCSM                  UCSB-B200-M3    262144     56
# 23       4            UCSM                  UCSB-B200-M4    131072     46
# 24       3            UCSM                  UCSB-B200-M4    262144     28.800001
# 25       3            UCSM                  UCSB-B200-M3    262144     56
# 26                    IntersightStandalone  UCSC-C240-M4SX  262144     72.799995
# 27                    IntersightStandalone  HXAF220C-M5SX   196608     44
# 28                    IntersightStandalone  HXAF220C-M5SX   196608     44
# 29                    IntersightStandalone  HXAF220C-M5SX   196608     44
# 30                    IntersightStandalone  HXAF220C-M5SX   196608     44
# 31                    IntersightStandalone  HXAF220C-M5SX   196608     44
# 32                    IntersightStandalone  HXAF220C-M5SX   196608     44
# 33                    IntersightStandalone  UCSC-C240-M5SX  262144     108
# 34                    IntersightStandalone  UCSC-C220-M5SX  786432     67.2
# 35                    IntersightStandalone  UCSC-C240-M5S   262144     55.199997
# 36                    IntersightStandalone  UCSC-C220-M4L   524288     88
# 37                    IntersightStandalone  UCSC-C220-M5L   196608     62.399998
# 38                    IntersightStandalone  UCSC-C240-M5SX  516096     151.2
# 39                    IntersightStandalone  UCSC-C220-M5SX  8192       10.200001
# 40                    IntersightStandalone  UCSC-C220-M5SX  16384      100
# 41                    IntersightStandalone  UCSC-C220-M5SX  3096576    123.200005
# 42       4            UCSM                  UCSC-C3K-M4SRB  49152      19.2
# 43       3            UCSM                  UCSB-EX-M4-1    49152      25
# 44       5            UCSM                  UCSB-B200-M4    49152      19.2
# 45       3            UCSM                  UCSB-EX-M4-1    49152      25
# 46       3            UCSM                  UCSB-EX-M4-1    49152      8.8
# 47       4            UCSM                  UCSC-C3K-M4SRB  49152      19.2
# 48       5            UCSM                  UCSB-B200-M4    49152      19.2
# 49       5            UCSM                  UCSB-B200-M4    49152      19.2
# 50       3            UCSM                  UCSB-EX-M4-1    49152      25
# 51       1            IntersightStandalone  UCS-S3260-M5SRB 262144     44
# 52       1            IntersightStandalone  UCS-S3260-M5SRB 454656     79.200005
# 53       6            UCSM                  UCSB-B480-M5    49152      41.6
# 54       6            UCSM                  UCSB-B200-M5    49152      20.8
# 55       6            UCSM                  UCSB-B200-M5    49152      20.8
# 56                    UCSM                  UCSC-C125       49152      4.6
# 57                    UCSM                  UCSC-C125       49152      4.6
# 58                    UCSM                  UCSC-C480-M5    49152      20
# 59                    UCSM                  UCSC-C240-M5S   49152      20
# 60                    UCSM                  UCSC-C220-M5L   49152      20
# 61                    UCSM                  UCSC-C240-M5SN  49152      20
# 62                    UCSM                  UCSC-C220-M5SN  49152      20
# 63                    UCSM                  HXAF240C-M5SX   49152      20
# 64                    UCSM                  HXAF220C-M5SX   49152      20
# 65                    UCSM                  HX240C-M5SX     49152      20
# 66       1            UCSM                  UCSB-B200-M4    262144     72.799995
# 67       1            UCSM                  UCSB-B200-M3    262144     56
# 68       1            UCSM                  UCSB-B200-M3    262144     56
# 69       1            UCSM                  UCSB-B200-M4    262144     28.800001
# 70       1            UCSM                  UCSB-B200-M4    262144     72.799995
# 71       1            UCSM                  UCSB-B200-M4    131072     72.799995
# 72       1            UCSM                  UCSB-B200-M5    131072     50.399998
# 73       1            UCSM                  UCSB-B200-M4    262144     52.800003
# 74       1            UCSM                  UCSB-B200-M5    131072     50.399998
# 75       1            UCSM                  UCSB-B200-M4    262144     52.800003
# 76       2            UCSM                  UCSC-C3X60-SVRNB 262144     44
# 77       1            UCSM                  UCSB-B200-M4    262144     52.800003
# 78       1            UCSM                  UCSB-B200-M5    131072     50.399998
# 79       1            UCSM                  UCSB-B200-M4    262144     52.800003
# 80       2            UCSM                  UCSC-C3X60-SVRNB 262144     44
# 81                    IntersightStandalone  UCSC-C240-M5L   196608     55.199997
# 82       1            UCSM                  UCSB-B200-M5    131072     50.399998
# 83       1            UCSM                  UCSB-B200-M4    262144     72.799995
# 84                    IntersightStandalone  UCSC-C240-M5SX  589824     84
# 85       1            Intersight            UCSB-B200-M5    128        96
# 86       1            Intersight            UCSB-B200-M5    128        96
# 87       1            Intersight            UCSB-B200-M5    768        160
# 88       1            Intersight            UCSB-B200-M5    768        160
# 89       1            Intersight            UCSB-B200-M5    768        160
# 90       1            Intersight            UCSB-B200-M5    768        160
# 91       1            Intersight            UCSB-B200-M5    768        160
# 92       1            Intersight            UCSB-B200-M5    768        160
# 93                    Intersight            UCSC-C220-M5SX  504        192
# 94                    Intersight            UCSC-C240-M5SX  384        160
# 95       1            UCSM                  UCSB-B200-M6    1048576    172.8
# 96       1            UCSM                  UCSB-B200-M6    1048576    172.8
# 97                    IntersightStandalone  UCSC-C220-M5SX  8192       10.200001
# 98                    IntersightStandalone  UCSC-C125       65536      76.8
# 99       1            Intersight            UCSB-B200-M5    384        160
# 100      1            Intersight            UCSB-B200-M5    384        160

# %% [markdown]
# **Next Step: Provide Title of the Next Step**
