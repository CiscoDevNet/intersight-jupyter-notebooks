# %% [markdown]
# # Using PowerShell with Intersight
#
# If you are familiar or proficient with PowerShell or PowerShell Core, you can take advantage of Intersight modules available for download from the [PowerShell Gallery](https://www.powershellgallery.com/). Enter the word `Intersight` in `Search PowerShell packages:` and click the resulting link produced by the search named `Intersight.PowerShell`.
# ![Intersight module returned by search](images/powershell_search_result_intersight.png)
#
# Notice the `Install Module -Name Intersight.PowerShell` command. That's the command used to install the module in your PowerShell environment.
#
# > Be sure you are in PowerShell itself before attempting to install the `Intersight.PowerShell` module. In PowerShell Core, the command to start PowerShell is `pwsh`

# %%
pwsh
# Out:
# PowerShell 7.1.3
# Copyright (c) Microsoft Corporation.
#
# https://aka.ms/powershell
# Type 'help' to get help.
#
# PS /Users/delgadm/Documents/intersight/intersight-jupyter-notebooks>

# %%
Install-Module -Name Intersight.PowerShell

# %% [markdown]
# ## Working with the PowerShell Intersight module
#
# Now that Intersight PowerShell module is installed, let's use it to connect to our Intersight environment. But first, you'll need credentials, such as your private key, from your Intersight account.
#
# ### Authenticate the user
#
# The private key is available in your Intersight account. Copy/paste the values and add them to a blank file named `SecretKey.txt` and make it available in the same directory as this PowerShell file. Also, get a hold of your API key and copy/paste the value into the `api_key_id` variable below.
#
# > The values below are ficticious and only serve as an example so they won't work in the real world. Be sure to enter the values for your account in the `ApiKeyId` variable below as well as the secret key in the `SecretKey.txt` otherwise the following steps will not work.

# %%
$onprem = @{
    BasePath = "https://intersight.com"
    ApiKeyId = "omitted on purpose add yours here"
    ApiKeyFilePath = Resolve-Path('/Users/delgadm/Documents/intersight/intersight-powershell/SecretKey.txt')
    HttpSingingHeader =  @("(request-target)", "Host", "Date", "Digest")
}

# %% [markdown]
# ### See available commands
#
# Now that you are authenticated, let's explore the list of available commands with the command `Get-Command -Module Intersight.Powershell`. There are many commands and to see what each one does along with any dependencies, visit [CiscoDevNet/intersight-powershell in the docs directory](https://github.com/CiscoDevNet/intersight-powershell/tree/master/docs) on GitHub.

# %%
Get-Command -Module Intersight.Powershell
# Out:
# CommandType     Name                                               Version    Source
# -----------     ----                                               -------    ------
# Cmdlet          Get-IntersightAaaAuditRecord                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAccessPolicy                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAdapterConfigPolicy                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAdapterExtEthInterface               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAdapterHostEthInterface              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAdapterHostFcInterface               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAdapterHostIscsiInterface            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAdapterUnit                          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAdapterUnitExpander                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceAppStatus                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceAutoRmaPolicy               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceBackup                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceBackupPolicy                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceCertificateSetting          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceDataExportPolicy            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceDeviceCertificate           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceDeviceClaim                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceDiagSetting                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceExternalSyslogSetting       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceFileSystemStatus            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceGroupStatus                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceImageBundle                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceNodeInfo                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceNodeStatus                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceReleaseNote                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceRemoteFileImport            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceRestore                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceSetupInfo                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceSystemInfo                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceSystemStatus                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceUpgrade                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightApplianceUpgradePolicy               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAssetClusterMember                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAssetDeployment                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAssetDeploymentDevice                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAssetDeviceConfiguration             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAssetDeviceConnectorManager          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAssetDeviceContractInformation       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAssetDeviceRegistration              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAssetSubscription                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAssetSubscriptionAccount             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAssetSubscriptionDeviceContractInfo… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightAssetTarget                          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBiosBootDevice                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBiosBootMode                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBiosPolicy                           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBiosSystemBootOrder                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBiosTokenSettings                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBiosUnit                             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBiosVfSelectMemoryRasConfiguration   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBootCddDevice                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBootDeviceBootMode                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBootDeviceBootSecurity               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBootHddDevice                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBootIscsiDevice                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBootNvmeDevice                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBootPchStorageDevice                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBootPrecisionPolicy                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBootPxeDevice                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBootSanDevice                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBootSdDevice                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBootUefiShellDevice                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBootUsbDevice                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightBootVmediaDevice                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilityAdapterUnitDescriptor      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilityCatalog                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilityChassisDescriptor          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilityChassisManufacturingDef    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilityCimcFirmwareDescriptor     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilityEquipmentPhysicalDef       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilityEquipmentSlotArray         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilityFanModuleDescriptor        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilityFanModuleManufacturingDef  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilityIoCardCapabilityDef        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilityIoCardDescriptor           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilityIoCardManufacturingDef     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilityPortGroupAggregationDef    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilityPsuDescriptor              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilityPsuManufacturingDef        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilityServerSchemaDescriptor     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilitySiocModuleCapabilityDef    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilitySiocModuleDescriptor       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilitySiocModuleManufacturingDef 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilitySwitchCapability           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilitySwitchDescriptor           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCapabilitySwitchManufacturingDef     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCertificatemanagementPolicy          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightChassisConfigChangeDetail            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightChassisConfigImport                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightChassisConfigResult                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightChassisConfigResultEntry             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightChassisIomProfile                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightChassisProfile                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCloudRegions                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCloudSkuContainerType                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCloudSkuDatabaseType                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCloudSkuInstanceType                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCloudSkuNetworkType                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCloudSkuVolumeType                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCloudTfcAgentpool                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCloudTfcOrganization                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCloudTfcWorkspace                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCommHttpProxyPolicy                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightComputeBlade                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightComputeBladeIdentity                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightComputeBoard                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightComputeMapping                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightComputePhysicalSummary               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightComputeRackUnit                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightComputeRackUnitIdentity              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightComputeServerSetting                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightComputeVmedia                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCondAlarm                            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCondAlarmAggregation                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCondHclStatus                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCondHclStatusDetail                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCondHclStatusJob                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightConfigExportedItem                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightConfigExporter                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightConfigImportedItem                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightConfigImporter                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightConfiguration                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightConnectorpackConnectorPackUpgrade    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightConnectorpackUpgradeImpact           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightCrdCustomResource                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightDeviceconnectorPolicy                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentChassis                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentChassisIdentity             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentChassisOperation            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentDeviceSummary               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentFan                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentFanControl                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentFanModule                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentFex                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentFexIdentity                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentFexOperation                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentFru                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentIdentitySummary             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentIoCard                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentIoCardOperation             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentIoExpander                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentLocatorLed                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentPsu                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentPsuControl                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentRackEnclosure               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentRackEnclosureSlot           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentSharedIoModule              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentSwitchCard                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentSystemIoController          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentTpm                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEquipmentTransceiver                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEtherHostPort                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEtherNetworkPort                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEtherPhysicalPort                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightEtherPortChannel                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightExternalsiteAuthorization            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricAppliancePcRole                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricApplianceRole                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricConfigChangeDetail             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricConfigResult                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricConfigResultEntry              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricElementIdentity                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricEthNetworkControlPolicy        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricEthNetworkGroupPolicy          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricEthNetworkPolicy               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricFcNetworkPolicy                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricFcoeUplinkPcRole               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricFcoeUplinkRole                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricFcUplinkPcRole                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricFcUplinkRole                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricFlowControlPolicy              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricLinkAggregationPolicy          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricLinkControlPolicy              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricMulticastPolicy                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricPcMember                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricPcOperation                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricPortMode                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricPortOperation                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricPortPolicy                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricServerRole                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricSwitchClusterProfile           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricSwitchControlPolicy            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricSwitchProfile                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricSystemQosPolicy                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricUplinkPcRole                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricUplinkRole                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricVlan                           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFabricVsan                           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFaultInstance                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFcPhysicalPort                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFcpoolFcBlock                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFcpoolLease                          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFcpoolPool                           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFcpoolPoolMember                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFcpoolUniverse                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFcPortChannel                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareBiosDescriptor               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareBoardControllerDescriptor    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareChassisUpgrade               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareCimcDescriptor               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareDimmDescriptor               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareDistributable                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareDistributableMeta            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareDriveDescriptor              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareDriverDistributable          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareEula                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareFirmwareSummary              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareGpuDescriptor                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareHbaDescriptor                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareIomDescriptor                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareMswitchDescriptor            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareNxosDescriptor               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwarePcieDescriptor               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwarePsuDescriptor                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareRunningFirmware              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareSasExpanderDescriptor        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareServerConfigurationUtilityD… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareStorageControllerDescriptor  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareSwitchUpgrade                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareUnsupportedVersionUpgrade    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareUpgrade                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareUpgradeImpactStatus          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightFirmwareUpgradeStatus                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightForecastCatalog                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightForecastDefinition                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightForecastInstance                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightGraphicsCard                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightGraphicsController                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHclDriverImage                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHclExemptedCatalog                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHclHyperflexSoftwareCompatibilityIn… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHclOperatingSystem                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHclOperatingSystemVendor             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexAlarm                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexAppCatalog                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexAutoSupportPolicy           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexBackupCluster               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexCapabilityInfo              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexCiscoHypervisorManager      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexCluster                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexClusterBackupPolicy         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexClusterBackupPolicyDeploym… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexClusterHealthCheckExecutio… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexClusterNetworkPolicy        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexClusterProfile              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexClusterReplicationNetworkP… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexClusterReplicationNetworkP… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexClusterStoragePolicy        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexConfigResult                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexConfigResultEntry           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexDataProtectionPeer          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexDatastoreStatistic          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexDevicePackageDownloadState  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexExtFcStoragePolicy          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexExtIscsiStoragePolicy       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexFeatureLimitExternal        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexFeatureLimitInternal        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHealth                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHealthCheckDefinition       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHealthCheckExecution        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHealthCheckExecutionSnapsh… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHealthCheckPackageChecksum  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHxapCluster                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHxapDatacenter              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHxapDvswitch                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHxapDvUplink                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHxapHost                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHxapHostInterface           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHxapHostVswitch             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHxapNetwork                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHxapVirtualDisk             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHxapVirtualMachine          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHxapVirtualMachineNetworkI… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexHxdpVersion                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexLicense                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexLocalCredentialPolicy       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexNode                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexNodeConfigPolicy            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexNodeProfile                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexProxySettingPolicy          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexServerFirmwareVersion       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexServerFirmwareVersionEntry  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexServerModel                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexSoftwareDistributionCompon… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexSoftwareDistributionEntry   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexSoftwareDistributionVersion 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexSoftwareVersionPolicy       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexStorageContainer            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexSysConfigPolicy             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexUcsmConfigPolicy            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexVcenterConfigPolicy         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexVmBackupInfo                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexVmImportOperation           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexVmRestoreOperation          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexVmSnapshotInfo              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexVolume                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightHyperflexWitnessConfiguration        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIaasConnectorPack                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIaasDeviceStatus                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIaasDiagnosticMessages               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIaasLicenseInfo                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIaasMostRunTasks                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIaasServiceRequest                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIaasUcsdInfo                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIaasUcsdManagedInfra                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIaasUcsdMessages                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamAccount                           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamAccountExperience                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamApiKey                            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamAppRegistration                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamBannerMessage                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamCertificate                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamCertificateRequest                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamDomainGroup                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamEndPointPrivilege                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamEndPointRole                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamEndPointUser                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamEndPointUserPolicy                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamEndPointUserRole                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamIdp                               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamIdpReference                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamIpAccessManagement                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamIpAddress                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamLdapGroup                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamLdapPolicy                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamLdapProvider                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamLocalUserPasswordPolicy           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamOAuthToken                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamPermission                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamPrivateKeySpec                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamPrivilege                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamPrivilegeSet                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamQualifier                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamResourceLimits                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamResourcePermission                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamResourceRoles                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamRole                              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamSecurityHolder                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamServiceProvider                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamSession                           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamSessionLimits                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamSystem                            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamTrustPoint                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamUser                              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamUserGroup                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIamUserPreference                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightInventoryDeviceInfo                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightInventoryDnMoBinding                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightInventoryGenericInventory            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightInventoryGenericInventoryHolder      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIpmioverlanPolicy                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIppoolBlockLease                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIppoolIpLease                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIppoolPool                           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIppoolPoolMember                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIppoolShadowBlock                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIppoolShadowPool                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIppoolUniverse                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIqnpoolBlock                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIqnpoolLease                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIqnpoolPool                          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIqnpoolPoolMember                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIqnpoolUniverse                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightIwotenantTenantStatus                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesAciCniApic                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesAciCniProfile              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesAciCniTenantClusterAlloca… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesAddonDefinition            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesAddonPolicy                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesAddonRepository            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesCatalog                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesCluster                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesClusterAddonProfile        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesClusterProfile             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesConfigResult               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesConfigResultEntry          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesContainerRuntimePolicy     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesDaemonSet                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesDeployment                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesIngress                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesNetworkPolicy              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesNode                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesNodeGroupProfile           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesPod                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesService                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesStatefulSet                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesSysConfigPolicy            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesTrustedRegistriesPolicy    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesVersion                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesVersionPolicy              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesVirtualMachineInfraConfig… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesVirtualMachineInfrastruct… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesVirtualMachineInstanceType 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKubernetesVirtualMachineNodeProfile  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKvmPolicy                            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKvmSession                           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKvmTunnel                            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightKvmVmConsole                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightLicenseAccountLicenseData            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightLicenseCustomerOp                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightLicenseIwoCustomerOp                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightLicenseIwoLicenseCount               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightLicenseLicenseInfo                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightLicenseLicenseReservationOp          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightLicenseSmartlicenseToken             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightLsServiceProfile                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightMacpoolIdBlock                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightMacpoolLease                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightMacpoolPool                          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightMacpoolPoolMember                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightMacpoolUniverse                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightManagementController                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightManagementEntity                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightManagementInterface                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightMemoryArray                          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightMemoryPersistentMemoryConfigResult   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightMemoryPersistentMemoryConfiguration  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightMemoryPersistentMemoryNamespace      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightMemoryPersistentMemoryNamespaceConf… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightMemoryPersistentMemoryPolicy         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightMemoryPersistentMemoryRegion         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightMemoryPersistentMemoryUnit           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightMemoryUnit                           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightMetaDefinition                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightMoMoRef                              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNetworkconfigPolicy                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNetworkElement                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNetworkElementSummary                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNetworkFcZoneInfo                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNetworkVlanPortInfo                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiApicCcoPost                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiApicFieldNotice                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiApicHweol                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiApicLatestMaintainedRelease    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiApicReleaseRecommend           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiApicSweol                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiDcnmCcoPost                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiDcnmFieldNotice                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiDcnmHweol                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiDcnmLatestMaintainedRelease    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiDcnmReleaseRecommend           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiDcnmSweol                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiFileDownloader                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiNiaMetadata                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiNibFileDownloader              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiNibMetadata                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiaapiVersionRegex                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryAaaLdapProviderDetails   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryAaaRadiusProviderDetails 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryAaaTacacsProviderDetails 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicCoreFileDetails      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicDbgexpRsExportDest   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicDbgexpRsTsScheduler  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicFanDetails           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicFexDetails           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicFlashDetails         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicNtpAuth              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicPsuDetails           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicRealmDetails         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicSnmpCommunityAccess… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicSnmpCommunityDetails 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicSnmpTrapDetails      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicSnmpVersionThreeDet… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicSysLogGrp            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicSysLogSrc            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicTransceiverDetails   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryApicUiPageCounts         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryAppDetails               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryDcnmFanDetails           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryDcnmFexDetails           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryDcnmModuleDetails        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryDcnmPsuDetails           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryDcnmTransceiverDetails   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryEpg                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryFabricModuleDetails      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryFault                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryHttpsAclContractDetails  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Get-IntersightNiatelemetryHttpsAclContractFilterM… 1.0.9.4403 Intersight.PowerShell
# ...
# Cmdlet          Set-IntersightKubernetesNodeGroupProfile           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightKubernetesSysConfigPolicy            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightKubernetesTrustedRegistriesPolicy    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightKubernetesVersion                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightKubernetesVersionPolicy              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightKubernetesVirtualMachineInfraConfig… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightKubernetesVirtualMachineInfrastruct… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightKubernetesVirtualMachineInstanceType 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightKubernetesVirtualMachineNodeProfile  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightKvmPolicy                            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightKvmSession                           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightLicenseAccountLicenseData            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightLicenseCustomerOp                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightLicenseIwoCustomerOp                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightLicenseIwoLicenseCount               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightLicenseLicenseInfo                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightLicenseLicenseReservationOp          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightLicenseSmartlicenseToken             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightLsServiceProfile                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightMacpoolPool                          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightManagementController                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightManagementEntity                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightManagementInterface                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightMemoryArray                          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightMemoryPersistentMemoryConfigResult   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightMemoryPersistentMemoryConfiguration  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightMemoryPersistentMemoryNamespace      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightMemoryPersistentMemoryNamespaceConf… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightMemoryPersistentMemoryPolicy         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightMemoryPersistentMemoryRegion         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightMemoryPersistentMemoryUnit           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightMemoryUnit                           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightNetworkconfigPolicy                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightNetworkElement                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightNetworkFcZoneInfo                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightNetworkVlanPortInfo                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightNotificationAccountSubscription      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightNtpPolicy                            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightOprsDeployment                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightOprsSyncTargetListMessage            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightOrganizationOrganization             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightOsConfigurationFile                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightPciDevice                            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightPciLink                              1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightPciSwitch                            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightPortGroup                            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightPortMacBinding                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightPortSubGroup                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightPowerPolicy                          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightProcessorUnit                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightRecoveryBackupConfigPolicy           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightRecoveryBackupProfile                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightRecoveryOnDemandBackup               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightRecoveryScheduleConfigPolicy         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightResourceGroup                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSdcardPolicy                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSdwanProfile                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSdwanRouterNode                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSdwanRouterPolicy                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSdwanVmanageAccountPolicy            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSecurityUnit                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightServerProfile                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightServerProfileTemplate                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSmtpPolicy                           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSnmpPolicy                           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSoftwareApplianceDistributable       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSoftwareHclMeta                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSoftwareHyperflexBundleDistributable 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSoftwareHyperflexDistributable       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSoftwareReleaseMeta                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSoftwarerepositoryAuthorization      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSoftwarerepositoryCategoryMapper     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSoftwarerepositoryCategoryMapperMod… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSoftwarerepositoryCategorySupportCo… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSoftwarerepositoryOperatingSystemFi… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSoftwarerepositoryRelease            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSoftwareSolutionDistributable        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSoftwareUcsdBundleDistributable      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSoftwareUcsdDistributable            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSolPolicy                            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSshPolicy                            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageController                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageDiskGroup                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageDiskGroupPolicy               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageEnclosure                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageEnclosureDisk                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageEnclosureDiskSlotEp           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageFlexFlashController           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageFlexFlashControllerProps      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageFlexFlashPhysicalDrive        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageFlexFlashVirtualDrive         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageFlexUtilController            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageFlexUtilPhysicalDrive         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageFlexUtilVirtualDrive          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageHitachiArray                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageNetAppCluster                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStoragePhysicalDisk                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStoragePhysicalDiskExtension         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStoragePhysicalDiskUsage             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStoragePureArray                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageSasExpander                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageSasPort                       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageSpan                          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageStoragePolicy                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageVdMemberEp                    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageVirtualDrive                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageVirtualDriveContainer         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightStorageVirtualDriveExtension         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightSyslogPolicy                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightTamAdvisoryCount                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightTamAdvisoryDefinition                1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightTamAdvisoryInfo                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightTamAdvisoryInstance                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightTamSecurityAdvisory                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightTechsupportmanagementCollectionCont… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightThermalPolicy                        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightTopSystem                            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightUuidpoolPool                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationHost                   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVirtualDisk            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVirtualMachine         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVmwareCluster          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVmwareDatacenter       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVmwareDatastore        1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVmwareDistributedNetw… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVmwareDistributedSwit… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVmwareFolder           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVmwareHost             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVmwareKernelNetwork    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVmwareNetwork          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVmwarePhysicalNetwork… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVmwareUplinkPort       1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVmwareVirtualDisk      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVmwareVirtualMachine   1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVmwareVirtualNetworkI… 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVirtualizationVmwareVirtualSwitch    1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVmediaPolicy                         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVmrcConsole                          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVnicEthAdapterPolicy                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVnicEthIf                            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVnicEthNetworkPolicy                 1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVnicEthQosPolicy                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVnicFcAdapterPolicy                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVnicFcIf                             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVnicFcNetworkPolicy                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVnicFcQosPolicy                      1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVnicIscsiAdapterPolicy               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVnicIscsiBootPolicy                  1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVnicIscsiStaticTargetPolicy          1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVnicLanConnectivityPolicy            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVnicSanConnectivityPolicy            1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightVrfVrf                               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightWorkflowBatchApiExecutor             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightWorkflowCustomDataTypeDefinition     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightWorkflowErrorResponseHandler         1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightWorkflowRollbackWorkflow             1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightWorkflowTaskDefinition               1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightWorkflowTaskInfo                     1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightWorkflowWorkflowDefinition           1.0.9.4403 Intersight.PowerShell
# Cmdlet          Set-IntersightWorkflowWorkflowInfo                 1.0.9.4403 Intersight.PowerShell

# %% [markdown]
# ### Get a list of physical compute inventory
#
# One simple yet useful example is that of retreiving physical inventory claimed in Intersight. Earlier we assigned a hash with key, value pairs containing the authentication credentials required for each PowerShell session.
#
# #### Set Intersight configuration
# To set the Intersight configuration, use the command `Set-IntersightConfiguration @onprem` where `@onprem` contains the hash set 2 steps earlier.

# %%
Set-IntersightConfiguration @onprem

# %% [markdown]
# #### Get Intersight configuration
#
# You can inspect the configuration settings after they are set with the `Set-IntersightConfiguration` command with `Get-IntersightConfiguration`.

# %% [markdown]
# #### Getting inventory of physical compute devices claimed in Intersight
#
# The command `Get-IntersightComputePhysicalSummary` returns all the physical compute devices claimed in Intersight along with details about each one.

# %%
Get-IntersightComputePhysicalSummary

# %%
Get-IntersightComputePhysicalSummary
# Out:
# ClassId              : ComputePhysicalSummary
# ObjectType           : ComputePhysicalSummary
# ManagementMode       : Intersight
# OperReason           : {}
# AdminPowerState      :
# AlarmSummary         : class ComputeAlarmSummary {
#                          class MoBaseComplexType {
#                            ClassId: 0
#                            ObjectType: 0
#                            AdditionalProperties:
#                        System.Collections.Generic.Dictionary`2[System.String,System.Object]
#                          }
#
#                          ClassId: ComputeAlarmSummary
#                          ObjectType: ComputeAlarmSummary
#                          Critical: 0
#                          Warning: 0
#                          AdditionalProperties:
#                        System.Collections.Generic.Dictionary`2[System.String,System.Object]
#                        }
#
# AssetTag             :
# AvailableMemory      : 512
# BiosPostComplete     : True
# ChassisId            : 1
# ConnectionStatus     :
# CpuCapacity          : 166.4
# DeviceMoId           : 60d3849c6f72612d33558fd9
# Dn                   : /redfish/v1/Systems/FCH243974Z5
# FaultSummary         : 0
# Firmware             : 4.1(5h)
# Ipv4Address          : 127.0.0.1
# KvmIpAddresses       : {}
# MemorySpeed          : 3200
# MgmtIpAddress        :
# Model                : UCSX-210C-M6
# Name                 : AA16-6454-1-2
# NumAdaptors          : 1
# NumCpuCores          : 64
# NumCpuCoresEnabled   : 64
# NumCpus              : 2
# NumEthHostInterfaces : 0
# NumFcHostInterfaces  : 0
# NumThreads           : 128
# OperPowerState       : on
# OperState            :
# Operability          :
# PlatformType         : IMCBlade
# Presence             : equipped
# Revision             :
# Rn                   :
# ScaledMode           :
# Serial               : FCH243974Z5
# ServerId             : 0
# ServiceProfile       :
# SlotId               : 2
# SourceObjectType     : compute.Blade
# TopologyScanStatus   :
# TotalMemory          : 524288
# UserLabel            :
# Uuid                 : 13580D52-2F86-4FFC-BFD5-21CF1ACF0D88
# Vendor               : Cisco Systems Inc
# InventoryDeviceInfo  :
# RegisteredDevice     : class AssetDeviceRegistrationRelationship {
#                          ActualInstance: class MoMoRef {
#                          ClassId: MoMoRef
#                          ObjectType: AssetDeviceRegistration
#                          Moid: 60d3849c6f72612d33558fd9
#                          Selector:
#                          Link: https://www.intersight.com/api/v1/asset/DeviceRegistrations/60d3849c
#                        6f72612d33558fd9
#                          AdditionalProperties:
#                        System.Collections.Generic.Dictionary`2[System.String,System.Object]
#                        }
#
#                        }
#
# AdditionalProperties : {[EquipmentChassis, {
#                          "ClassId": "mo.MoRef",
#                          "Moid": "60d383e86176752d33534964",
#                          "ObjectType": "equipment.Chassis",
#                          "link": "https://www.intersight.com/api/v1/equipment/Chasses/60d383e861767
#                        52d33534964"
#                        }]}
# AccountMoid          : 60c9136c7564612d334c51db
# CreateTime           : 6/23/2021 7:01:30 PM
# DomainGroupMoid      : 60c9136c7564612d334c51dc
# ModTime              : 8/12/2021 8:01:33 PM
# Moid                 : 60d3850a6176752d3353eccb
# Owners               : {60c9136c7564612d334c51db, 60d377506f72612d3084f1c6,
#                        60d3849c6f72612d33558fd9}
# SharedScope          :
# Tags                 : {class MoTag {
#                          Key: Intersight.LicenseTier
#                          Value: Premier
#                          AdditionalProperties:
#                        System.Collections.Generic.Dictionary`2[System.String,System.Object]
#                        }
#                        }
# VersionContext       :
# Ancestors            : {class MoBaseMoRelationship {
#                          ActualInstance: class MoMoRef {
#                          ClassId: MoMoRef
#                          ObjectType: EquipmentChassis
#                          Moid: 60d383e86176752d33534964
#                          Selector:
#                          Link:
#                        https://www.intersight.com/api/v1/equipment/Chasses/60d383e86176752d33534964
#                          AdditionalProperties:
#                        System.Collections.Generic.Dictionary`2[System.String,System.Object]
#                        }
#
#                        }
#                        }
# Parent               : class MoBaseMoRelationship {
#                          ActualInstance: class MoMoRef {
#                          ClassId: MoMoRef
#                          ObjectType: EquipmentChassis
#                          Moid: 60d383e86176752d33534964
#                          Selector:
#                          Link:
#                        https://www.intersight.com/api/v1/equipment/Chasses/60d383e86176752d33534964
#                          AdditionalProperties:
#                        System.Collections.Generic.Dictionary`2[System.String,System.Object]
#                        }
#
#                        }
#
# PermissionResources  : {class MoBaseMoRelationship {
#                          ActualInstance: class MoMoRef {
#                          ClassId: MoMoRef
#                          ObjectType: OrganizationOrganization
#                          Moid: 60c9136f6972652d31ab7b71
#                          Selector:
#                          Link: https://www.intersight.com/api/v1/organization/Organizations/60c9136
#                        f6972652d31ab7b71
#                          AdditionalProperties:
#                        System.Collections.Generic.Dictionary`2[System.String,System.Object]
#                        }
#
#                        }
#                        , class MoBaseMoRelationship {
#                          ActualInstance: class MoMoRef {
#                          ClassId: MoMoRef
#                          ObjectType: OrganizationOrganization
#                          Moid: 60d3784d6972652d3101645f
#                          Selector:
#                          Link: https://www.intersight.com/api/v1/organization/Organizations/60d3784
#                        d6972652d3101645f
#                          AdditionalProperties:
#                        System.Collections.Generic.Dictionary`2[System.String,System.Object]
#                        }
#
#                        }
#                        }
# DisplayNames         :
#
# ClassId              : ComputePhysicalSummary
# ObjectType           : ComputePhysicalSummary
# ManagementMode       : Intersight
# OperReason           : {}
# AdminPowerState      :
# AlarmSummary         : class ComputeAlarmSummary {
#                          class MoBaseComplexType {
#                            ClassId: 0
#                            ObjectType: 0
#                            AdditionalProperties:
#                        System.Collections.Generic.Dictionary`2[System.String,System.Object]
#                          }
#
#                          ClassId: ComputeAlarmSummary
#                          ObjectType: ComputeAlarmSummary
#                          Critical: 0
#                          Warning: 0
#                          AdditionalProperties:
#                        System.Collections.Generic.Dictionary`2[System.String,System.Object]
#                        }
#
# AssetTag             :
# AvailableMemory      : 512
# BiosPostComplete     : True
# ChassisId            : 1
# ConnectionStatus     :
# CpuCapacity          : 166.4
# DeviceMoId           : 60d384a66f72612d33559224
# Dn                   : /redfish/v1/Systems/FCH243974UU
# FaultSummary         : 0
# Firmware             : 4.1(5h)
# Ipv4Address          : 127.0.0.1
# KvmIpAddresses       : {}
# MemorySpeed          : 3200
# MgmtIpAddress        :
# Model                : UCSX-210C-M6
# Name                 : AA16-6454-1-1
# NumAdaptors          : 1
# NumCpuCores          : 64
# NumCpuCoresEnabled   : 64
# NumCpus              : 2
# NumEthHostInterfaces : 0
# NumFcHostInterfaces  : 0
# NumThreads           : 128
# OperPowerState       : on
# OperState            :
# Operability          :
# PlatformType         : IMCBlade
# Presence             : equipped
# Revision             :
# Rn                   :
# ScaledMode           :
# Serial               : FCH243974UU
# ServerId             : 0
# ServiceProfile       :
# SlotId               : 1
# SourceObjectType     : compute.Blade
# TopologyScanStatus   :
# TotalMemory          : 524288
# UserLabel            :
# Uuid                 : 524CCB06-0DFC-4403-A072-FB88A66A0BB5
# Vendor               : Cisco Systems Inc
# InventoryDeviceInfo  :
# RegisteredDevice     : class AssetDeviceRegistrationRelationship {
#                          ActualInstance: class MoMoRef {
#                          ClassId: MoMoRef
#                          ObjectType: AssetDeviceRegistration
#                          Moid: 60d384a66f72612d33559224
#                          Selector:
#                          Link: https://www.intersight.com/api/v1/asset/DeviceRegistrations/60d384a6
#                        6f72612d33559224
#                          AdditionalProperties:
#                        System.Collections.Generic.Dictionary`2[System.String,System.Object]
#                        }
#
#                        }
#
# AdditionalProperties : {[EquipmentChassis, {
#                          "ClassId": "mo.MoRef",
#                          "Moid": "60d383e86176752d33534964",
#                          "ObjectType": "equipment.Chassis",
#                          "link": "https://www.intersight.com/api/v1/equipment/Chasses/60d383e861767
#                        52d33534964"
#                        }]}
# AccountMoid          : 60c9136c7564612d334c51db
# CreateTime           : 6/23/2021 7:01:40 PM
# DomainGroupMoid      : 60c9136c7564612d334c51dc
# ModTime              : 8/12/2021 8:02:45 PM
# Moid                 : 60d385146176752d3353f209
# Owners               : {60c9136c7564612d334c51db, 60d377506f72612d3084f1c6,
#                        60d384a66f72612d33559224}
# SharedScope          :
# Tags                 : {class MoTag {
#                          Key: Intersight.LicenseTier
#                          Value: Premier
#                          AdditionalProperties:
#                        System.Collections.Generic.Dictionary`2[System.String,System.Object]
#                        }
#                        }
# VersionContext       :
# Ancestors            : {class MoBaseMoRelationship {
#                          ActualInstance: class MoMoRef {
#                          ClassId: MoMoRef
#                          ObjectType: EquipmentChassis
#                          Moid: 60d383e86176752d33534964
#                          Selector:
#                          Link:
#                        https://www.intersight.com/api/v1/equipment/Chasses/60d383e86176752d33534964
#                          AdditionalProperties:
#                        System.Collections.Generic.Dictionary`2[System.String,System.Object]
#                        }
#
#                        }
#                        }
# Parent               : class MoBaseMoRelationship {
#                          ActualInstance: class MoMoRef {
#                          ClassId: MoMoRef
#                          ObjectType: EquipmentChassis
#                          Moid: 60d383e86176752d33534964
#                          Selector:
#                          Link:
#                        https://www.intersight.com/api/v1/equipment/Chasses/60d383e86176752d33534964
#                          AdditionalProperties:
#                        System.Collections.Generic.Dictionary`2[System.String,System.Object]
#                        }
#
#                        }
#
# PermissionResources  : {class MoBaseMoRelationship {
#                          ActualInstance: class MoMoRef {
#                          ClassId: MoMoRef
#                          ObjectType: OrganizationOrganization
#                          Moid: 60c9136f6972652d31ab7b71
#                          Selector:
#                          Link: https://www.intersight.com/api/v1/organization/Organizations/60c9136
#                        f6972652d31ab7b71
#                          AdditionalProperties:
#                        System.Collections.Generic.Dictionary`2[System.String,System.Object]
#                        }
#
#                        }
#                        , class MoBaseMoRelationship {
#                          ActualInstance: class MoMoRef {
#                          ClassId: MoMoRef
#                          ObjectType: OrganizationOrganization
#                          Moid: 60d3784d6972652d3101645f
#                          Selector:
#                          Link: https://www.intersight.com/api/v1/organization/Organizations/60d3784
#                        d6972652d3101645f
#                          AdditionalProperties:
#                        System.Collections.Generic.Dictionary`2[System.String,System.Object]
#                        }
#
#                        }
#                        }
# DisplayNames         :

# %% [markdown]
# #### Using help to learn more about a command
# There are a number of parameters you can pass to the command but for simplicity we run the command without parameters and inspect the output. As mentioned earlier, the documentation avaialble on GitHub provides a description of each command but you can also get information with the `help Get-IntersightComputePhysicalSummary` command.

# %%
help Get-IntersightComputePhysicalSummary
# Out:
# ﻿
# NAME
#     Get-IntersightComputePhysicalSummary
#
# SYNTAX
#     Get-IntersightComputePhysicalSummary [-Name <string>] [-Organization <OrganizationOrganizationRelationship>] [-Json] [<CommonParameters>]
#
#     Get-IntersightComputePhysicalSummary [-Count <bool>] [-InlineCount {allpages | none}] [-Select <string>] [-Filter <string>] [-Expand <string>]
#     [-Skip <int>] [-Top <int>] [-At <string>] [-Orderby <string>] [-Apply <string>] [-Tag <string>] [-Json] [<CommonParameters>]
#
#
# PARAMETERS
#     -Apply <string>
#
#         Required?                    false
#         Position?                    Named
#         Accept pipeline input?       false
#         Parameter set name           QueryParam
#         Aliases                      None
#         Dynamic?                     false
#         Accept wildcard characters?  false
#
#     -At <string>
#
#         Required?                    false
#         Position?                    Named
#         Accept pipeline input?       false
#         Parameter set name           QueryParam
#         Aliases                      None
#         Dynamic?                     false
#         Accept wildcard characters?  false
#
#     -Count <bool>
#
#         Required?                    false
#         Position?                    Named
#         Accept pipeline input?       false
#         Parameter set name           QueryParam
#         Aliases                      None
#         Dynamic?                     false
#         Accept wildcard characters?  false
#
#     -Expand <string>
#
#         Required?                    false
#         Position?                    Named
#         Accept pipeline input?       false
#         Parameter set name           QueryParam
#         Aliases                      None
#         Dynamic?                     false
#         Accept wildcard characters?  false
#
#     -Filter <string>
#
#         Required?                    false
#         Position?                    Named
#         Accept pipeline input?       false
#         Parameter set name           QueryParam
#         Aliases                      None
#         Dynamic?                     false
#         Accept wildcard characters?  false
#
#     -InlineCount <string>
#
#         Required?                    false
#         Position?                    Named
#         Accept pipeline input?       false
#         Parameter set name           QueryParam
#         Aliases                      None
#         Dynamic?                     false
#         Accept wildcard characters?  false
#
#     -Json
#
#         Required?                    false
#         Position?                    Named
#         Accept pipeline input?       true (ByPropertyName)
#         Parameter set name           (All)
#         Aliases                      None
#         Dynamic?                     false
#         Accept wildcard characters?  false
#
#     -Name <string>
#
#         Required?                    false
#         Position?                    Named
#         Accept pipeline input?       false
#         Parameter set name           CmdletParam
#         Aliases                      None
#         Dynamic?                     false
#         Accept wildcard characters?  false
#
#     -Orderby <string>
#
#         Required?                    false
#         Position?                    Named
#         Accept pipeline input?       false
#         Parameter set name           QueryParam
#         Aliases                      None
#         Dynamic?                     false
#         Accept wildcard characters?  false
#
#     -Organization <OrganizationOrganizationRelationship>
#
#         Required?                    false
#         Position?                    Named
#         Accept pipeline input?       true (ByValue, ByPropertyName)
#         Parameter set name           CmdletParam
#         Aliases                      None
#         Dynamic?                     false
#         Accept wildcard characters?  false
#
#     -Select <string>
#
#         Required?                    false
#         Position?                    Named
#         Accept pipeline input?       false
#         Parameter set name           QueryParam
#         Aliases                      None
#         Dynamic?                     false
#         Accept wildcard characters?  false
#
#     -Skip <int>
#
#         Required?                    false
#         Position?                    Named
#         Accept pipeline input?       false
#         Parameter set name           QueryParam
#         Aliases                      None
#         Dynamic?                     false
#         Accept wildcard characters?  false
#
#     -Tag <string>
#
#         Required?                    false
#         Position?                    Named
#         Accept pipeline input?       false
#         Parameter set name           QueryParam
#         Aliases                      None
#         Dynamic?                     false
#         Accept wildcard characters?  false
#
#     -Top <int>
#
#         Required?                    false
#         Position?                    Named
#         Accept pipeline input?       false
#         Parameter set name           QueryParam
#         Aliases                      None
#         Dynamic?                     false
#         Accept wildcard characters?  false
#
#     <CommonParameters>
#         This cmdlet supports the common parameters: Verbose, Debug,
#         ErrorAction, ErrorVariable, WarningAction, WarningVariable,
#         OutBuffer, PipelineVariable, and OutVariable. For more information, see
#         about_CommonParameters (https://go.microsoft.com/fwlink/?LinkID=113216).
#
#
# INPUTS
#     Intersight.Model.OrganizationOrganizationRelationship
#     System.Management.Automation.SwitchParameter
#
#
# OUTPUTS
#     System.Object
#
# ALIASES
#     None
#
#
# REMARKS
#     None

# %% [markdown]
# #### Getting the number of physical compute devices claimed in Intersight
#
# One way to get a list of physical devices claimed in Intersight is to add `-InlineCount allpages` as a parameter to the `Get-IntersightComputePhysicalSummary` command.

# %%
Get-IntersightComputePhysicalSummary -InlineCount allpages
# Out:
# Count Results
# ----- -------
#     2 {class ComputePhysicalSummary {…

# %% [markdown]
# ### Final result - get a list of of physical compute devices claimed in Intersight
#
# Alas, we reach the goal of this exercise which is to display each physical device claimed in Intersight along with details such as the available memory, serial number, and its managed mode.
#
# > Intersight Managed Mode (IMM) is a new architecture that manages the UCS Fabric Interconnected systems through a Redfish-based standard model. If you are familiar with the UCS blades, it means the Fabric Interconnect is fully managed by Intersight. Instead of having the familiar UCSM (UCS Manager) interface available directly from the Fabric Interconnect, the interface and all of the Fabric Interconnect operations are managed by Intersight.

# %%
Get-IntersightComputePhysicalSummary | select ChassisId,Serial,ManagementMode,Model,AvailableMemory,CpuCapacity
# Out:
# ChassisId       : 1
# Serial          : FCH243974Z5
# ManagementMode  : Intersight
# Model           : UCSX-210C-M6
# AvailableMemory : 512
# CpuCapacity     : 166.4
#
# ChassisId       : 1
# Serial          : FCH243974UU
# ManagementMode  : Intersight
# Model           : UCSX-210C-M6
# AvailableMemory : 512
# CpuCapacity     : 166.4
