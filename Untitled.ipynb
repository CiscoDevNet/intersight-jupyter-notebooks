# %%
pwsh
# Out:
# PowerShell 7.1.4
# Copyright (c) Microsoft Corporation.
#
# https://aka.ms/powershell
# Type 'help' to get help.
#
# PS /Users/delgadm/Documents/intersight/intersight-jupyter-notebooks>

# %%
Get-Module -ListAvailable
# Out:
#     Directory: /Users/delgadm/.dotnet/tools/.store/microsoft.dotnet-interactive/1.0.210301/microsof
# t.dotnet-interactive/1.0.210301/tools/net5.0/any/Modules
#
# ModuleType Version    PreRelease Name                                PSEdition ExportedCommands
# ---------- -------    ---------- ----                                --------- ----------------
# Manifest   0.1.0                 Microsoft.DotNet.Interactive.Power… Core      {Enter-AzShell, New…
# Manifest   1.2.5                 Microsoft.PowerShell.Archive        Desk      {Compress-Archive, …
# Script     1.4.6                 PackageManagement                   Desk      {Find-Package, Get-…
# Script     2.2.3                 PowerShellGet                       Desk      {Find-Command, Find…
# Binary     2.0.3                 ThreadJob                           Desk      Start-ThreadJob
#
#     Directory: /Users/delgadm/.local/share/powershell/Modules
#
# ...

# %%
Get-Command -Module Cisco.IMC
# Out:
# CommandType     Name                                               Version    Source
# -----------     ----                                               -------    ------
# Alias           Acknowledge-ImcFault                               3.0.1.2    Cisco.IMC
# Alias           Add-ImcMo                                          3.0.1.2    Cisco.IMC
# Alias           Backup-ImcBiosProfile                              3.0.1.2    Cisco.IMC
# Alias           Clear-ImcBootDrive                                 3.0.1.2    Cisco.IMC
# Alias           Clear-ImcForeignConfig                             3.0.1.2    Cisco.IMC
# Alias           Clear-ImcKmipLogin                                 3.0.1.2    Cisco.IMC
# Alias           Clear-ImcKmipServer                                3.0.1.2    Cisco.IMC
# Alias           Clear-ImcOneTimePrecisionBootDevice                3.0.1.2    Cisco.IMC
# Alias           Disable-ImcChassisLocatorLed                       3.0.1.2    Cisco.IMC
# ...

# %%
Connect-Imc
# Out:
# cmdlet Connect-Imc at command pipeline position 1
# Supply values for the following parameters:
# Name[0]: 10.194.239.215
# Name[1]:
# Credential:
# User: admin
# Password for user admin: ········
#
#
# Model                       : UCSC-C240-M4L
# ModelType                   : Classic
# NumPendingConfigs           : 0
# Imc                         : C240-FCH2012V01L
# Cookie                      : f5d36b5667/3f24062b-cb98-74ee-6daf-5a02eec3480f
# Domains                     :
# LastUpdateTime              : 9/10/2021 3:58:48 PM
# Name                        : 10.194.239.215
# NoSsl                       : False
# NumWatchers                 : 0
# Port                        : 443
# Priv                        : {admin}
# PromptOnCompleteTransaction : False
# Proxy                       :
# RefreshPeriod               : 600
# SessionId                   : 6
# TransactionInProgress       : False
# Uri                         : https://10.194.239.215
# ...

# %%
Get-ImcFirmwareRunning
# Out:
# Deployment   : system
# Description  : Cisco Device Connector currently running firmware version
# Type         : device-connector
# Version      : 1.0.9-1756
# Imc          : C240-FCH2012V01L
# Dn           : sys/cloud-mgmt/device-connector/mgmt/fw-system
# Rn           : fw-system
# Status       :
# XtraProperty : {}
#
# Deployment   : boot-loader
# Description  : Cisco VIC adapter currently running boot loader firmware version
# Type         : adaptor
# Version      : 4.0(5b)
# Imc          : C240-FCH2012V01L
# Dn           : sys/rack-unit-1/adaptor-MLOM/mgmt/fw-boot-loader
# Rn           : fw-boot-loader
# Status       :
# XtraProperty : {}
#
# Deployment   : system
# Description  : Cisco VIC adapter currently running firmware version
# Type         : adaptor
# Version      : 4.4(1g)
# Imc          : C240-FCH2012V01L
# Dn           : sys/rack-unit-1/adaptor-MLOM/mgmt/fw-system
# Rn           : fw-system
# Status       :
# XtraProperty : {}
#
# Deployment   : boot-loader
# ...
